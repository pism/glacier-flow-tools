# %% [markdown]
# Preamble

# %%
import numpy as np
import pandas as pd
import xarray as xr
import geopandas as gp
from shapely import Point
import pylab as plt

from glacier_flow_tools.interpolation import velocity
from glacier_flow_tools.pathlines import (
    compute_pathline,
    series_to_pathline_geopandas_dataframe,
    pathline_to_line_geopandas_dataframe,
)
from glacier_flow_tools.utils import register_colormaps
register_colormaps()

# %% [markdown]
# compute_pathline Function

# %%
from typing import Callable, Dict, Tuple, Union

import geopandas as gp
import numpy as np
from numpy import ndarray
from numpy.linalg import norm
from shapely.geometry import LineString, Point
from tqdm import tqdm as tqdm_script
from tqdm.notebook import tqdm as tqdm_notebook
from xarray import DataArray

from glacier_flow_tools.gaussian_random_fields import (
    distrib_normal,
    generate_field,
    power_spectrum,
)
from glacier_flow_tools.geom import distances

def compute_pathline(
    point: Union[list, ndarray, Point],
    f: Callable,
    f_args: Tuple,
    start_time: float = 0.0,
    end_time: float = 1000.0,
    hmin: float = 0.0001,
    hmax: float = 10,
    tol: float = 1e-4,
    v_threshold: float = 0.0,
    notebook: bool = False,
    progress: bool = False,
    progress_kwargs: Dict = {"leave": False, "position": 0},
) -> Tuple[ndarray, ndarray, ndarray, ndarray]:
    """
    Compute a pathline using Runge-Kutta-Fehlberg integration.

    This function computes a pathline, which is a trajectory traced by a particle in a fluid flow. The pathline is computed by integrating the velocity field using the Runge-Kutta-Fehlberg method. The function is unit-agnostic, requiring the user to ensure consistency of units. For example, if the velocity field is given in m/yr, the `start_time` and `end_time` are assumed to be in years.

    Parameters
    ----------
    point : list, ndarray, or shapely.Point
        Starting point of the pathline.
    f : callable
        Function that computes the derivative of the state at a given point.
    f_args : tuple
        Additional arguments to pass to the function `f`.
    start_time : float, optional
        The start time of integration. Default is 0.0.
    end_time : float, optional
        The end time of integration. Default is 1000.0.
    hmin : float, optional
        The minimum step size for the integration. Default is 0.0001.
    hmax : float, optional
        The maximum step size for the integration. Default is 10.
    tol : float, optional
        The error tolerance for the integration. Default is 1e-4.
    v_threshold : float, optional
        A velocity threshold below which the solver stops. Default is 0.
    notebook : bool, optional
        If True, a progress bar is displayed in a Jupyter notebook. Default is False.
    progress : bool, optional
        If True, a progress bar is displayed. Default is False.
    progress_kwargs : dict, optional
        Additional keyword arguments for the progress bar. Default is {"leave": False, "position": 0}.

    Returns
    -------
    pts : ndarray
        The points along the pathline.
    velocities : ndarray
        The velocity at each point along the pathline.
    pts_error_estimate : ndarray
        Error estimate at each point along the pathline.

    Examples
    ----------
    >>> import numpy as np
    >>> from shapely.geometry import Point
    >>> def velocity_field(point, t):
    >>>     x, y = point
    >>>     return np.array([-y, x])
    >>> point = [1, 0]
    >>> pts, v, _ = compute_pathline(point, velocity_field, (), start_time=0, end_time=2*np.pi)
    """

    a2 = 2.500000000000000e-01  #  1/4
    a3 = 3.750000000000000e-01  #  3/8
    a4 = 9.230769230769231e-01  #  12/13
    a5 = 1.000000000000000e00  #  1
    a6 = 5.000000000000000e-01  #  1/2

    b21 = 2.500000000000000e-01  #  1/4
    b31 = 9.375000000000000e-02  #  3/32
    b32 = 2.812500000000000e-01  #  9/32
    b41 = 8.793809740555303e-01  #  1932/2197
    b42 = -3.277196176604461e00  # -7200/2197
    b43 = 3.320892125625853e00  #  7296/2197
    b51 = 2.032407407407407e00  #  439/216
    b52 = -8.000000000000000e00  # -8
    b53 = 7.173489278752436e00  #  3680/513
    b54 = -2.058966861598441e-01  # -845/4104
    b61 = -2.962962962962963e-01  # -8/27
    b62 = 2.000000000000000e00  #  2
    b63 = -1.381676413255361e00  # -3544/2565
    b64 = 4.529727095516569e-01  #  1859/4104
    b65 = -2.750000000000000e-01  # -11/40

    r1 = 2.777777777777778e-03  #  1/360
    r3 = -2.994152046783626e-02  # -128/4275
    r4 = -2.919989367357789e-02  # -2197/75240
    r5 = 2.000000000000000e-02  #  1/50
    r6 = 3.636363636363636e-02  #  2/55

    c1 = 1.157407407407407e-01  #  25/216
    c3 = 5.489278752436647e-01  #  1408/2565
    c4 = 5.353313840155945e-01  #  2197/4104
    c5 = -2.000000000000000e-01  # -1/5

    if isinstance(point, Point):
        point = np.squeeze(np.array(point.coords.xy).reshape(1, -1))

    x = point
    t = start_time
    h = hmax

    pts = np.empty((0, len(x)), dtype=float)
    velocities = np.empty((0, len(x)), dtype=float)
    time = np.empty(0, dtype=float)
    error_estimate = np.empty(0, dtype=float)

    pts = np.vstack([pts, x])
    vel = f(point, start_time, *f_args)
    v = np.sqrt(vel[0] ** 2 + vel[1] ** 2)
    velocities = np.vstack([velocities, vel])
    time = np.append(time, start_time)
    error_estimate = np.append(error_estimate, 0.0)

    p_bar = tqdm_notebook if notebook else tqdm_script
    with p_bar(desc="Integrating pathline", total=end_time, **progress_kwargs) if progress else nullcontext():
        while (t < end_time) and (v > v_threshold):

            if np.isclose(t + h, end_time, rtol=1e-5):
                h = end_time - t

            k1 = h * f(x, t, *f_args)
            if np.any(np.isnan(k1)):
                return np.array([[np.nan, np.nan]]), np.array([[np.nan, np.nan]]), np.array([t]), np.array([np.nan])
            k2 = h * f(x + b21 * k1, t + a2 * h, *f_args)
            if np.any(np.isnan(k2)):
                return np.array([[np.nan, np.nan]]), np.array([[np.nan, np.nan]]), np.array([t]), np.array([np.nan])
            k3 = h * f(x + b31 * k1 + b32 * k2, t + a3 * h, *f_args)
            if np.any(np.isnan(k3)):
                return np.array([[np.nan, np.nan]]), np.array([[np.nan, np.nan]]), np.array([t]), np.array([np.nan])
            k4 = h * f(x + b41 * k1 + b42 * k2 + b43 * k3, t + a4 * h, *f_args)
            if np.any(np.isnan(k4)):
                return np.array([[np.nan, np.nan]]), np.array([[np.nan, np.nan]]), np.array([t]), np.array([np.nan])
            k5 = h * f(x + b51 * k1 + b52 * k2 + b53 * k3 + b54 * k4, t + a5 * h, *f_args)
            if np.any(np.isnan(k5)):
                return np.array([[np.nan, np.nan]]), np.array([[np.nan, np.nan]]), np.array([t]), np.array([np.nan])
            k6 = h * f(x + b61 * k1 + b62 * k2 + b63 * k3 + b64 * k4 + b65 * k5, t + a6 * h, *f_args)
            if np.any(np.isnan(k6)):
                return np.array([[np.nan, np.nan]]), np.array([[np.nan, np.nan]]), np.array([t]), np.array([np.nan])

            r = norm(r1 * k1 + r3 * k3 + r4 * k4 + r5 * k5 + r6 * k6) / h
            if r <= tol:

                pts = np.append(pts, [x], axis=0)
                velocities = np.append(velocities, [vel], axis=0)
                time = np.append(time, t)
                error_estimate = np.append(error_estimate, r)

                t = t + h
                x = x + c1 * k1 + c3 * k3 + c4 * k4 + c5 * k5

                vel = f(x, t, *f_args)
                v = np.sqrt(vel[0] ** 2 + vel[1] ** 2)

            s = (tol / r) ** 0.25
            h = np.minimum(h * s, hmax)

            if (h < hmin) and (t < end_time):
                print(
                    f"Error: Could not converge to the required tolerance {tol:e} with minimum stepsize  {hmin:e} at t={t}"
                )
                continue

    return pts, velocities, time, error_estimate

# %% [markdown]
# Batch Prossesing to Generate Flowlines from Seeding Points

# %%
# === BATCH PROCESSING FOR MULTIPLE GLACIERS ===

import os
import glob
from tqdm import tqdm
import rasterio
import geopandas as gp
import numpy as np
from shapely.geometry import Point
import pandas as pd
from contextlib import nullcontext

#Parameters for pathline computation
hmin = 0.01
hmax = 1
tol = 0.1 #was 1 before
start_time = 0
end_time = 1000
v_threshold = 100
spacing = 200  # spacing for seed points, was 500 before, matches GrIMP mosaic resolution


import os
import pandas as pd
import geopandas as gp
from shapely.geometry import Point
from tqdm import tqdm

# Input CSV
coords_path = '/Users/jagon/Documents/Projects/Collabs/Jessica Badgeley/New Points v3/Input/Box Coordinates/box_sp_gl40_v3.csv'
df_coords = pd.read_csv(coords_path)

# For collecting stats if needed
all_glacier_stats = []

# === PROCESS EACH GLACIER ===
for _, row in tqdm(df_coords.iterrows(), total=len(df_coords), desc="Processing glaciers"):
    try:
        feature_id = row.get('feature_ID', 'unknown')
        glacier_id = row.get('glacier_ID', 'unknown')
        glacier_name = row.get('glacier_name', 'unknown')

        sp_path = '/Users/jagon/Documents/Projects/Collabs/Jessica Badgeley/New Points v3/Input/Starting Points'
        os.makedirs(sp_path, exist_ok=True)

        seed_points = []
        seed_metadata = []
        used_box_nums = set()

        # Identify all box numbers dynamically (even if some unused)
        box_nums = set()
        for col in row.index:
            if col.startswith("coord_1_"):
                num = col.split("_")[2]
                box_nums.add(num)

        # For each box, generate seed points
        for num in sorted(box_nums, key=int):
            coord1_col = f"coord_1_{num}"
            coord2_col = f"coord_2_{num}"

            # Skip if any of the coords are NaN
            if pd.isna(row.get(coord1_col)) or pd.isna(row.get(coord2_col)):
                continue

            # Parse coordinates from strings
            x1_str, y1_str = str(row[coord1_col]).split(",")
            x2_str, y2_str = str(row[coord2_col]).split(",")
            x1, y1 = float(x1_str), float(y1_str)
            x2, y2 = float(x2_str), float(y2_str)

            # Order coordinates
            x_start, x_end = sorted([x1, x2])
            y_start, y_end = sorted([y1, y2])

            # Generate ranges
            x_coords = range(int(x_start), int(x_end), spacing)
            y_coords = range(int(y_start), int(y_end), spacing)

            # Create points and metadata
            if x_coords and y_coords:
                used_box_nums.add(num)

            for x in x_coords:
                for y in y_coords:
                    seed_points.append(Point(x, y))
                    seed_metadata.append({
                        'glacier_ID': glacier_id,
                        'feature_ID': feature_id,
                        'glacier_name': glacier_name,
                        'box_number': num,
                        'x': x,
                        'y': y
                    })

        print(f"For Glacier {glacier_name} (ID:{feature_id}) generated {len(seed_points)} seeding points across {len(used_box_nums)} boxes.")

        # Build GeoDataFrame
        glacier_gdf = gp.GeoDataFrame(seed_metadata, geometry=seed_points, crs="EPSG:3413")

        # Save GeoJSON
        filename = f"sp_{feature_id}.geojson"
        filepath = os.path.join(sp_path, filename)
        glacier_gdf.to_file(filepath, driver='GeoJSON')

        # Keep for next steps
        starting_points_df = glacier_gdf

        # Build GeoDataFrame
        glacier_gdf = gp.GeoDataFrame(seed_metadata, geometry=seed_points, crs="EPSG:3413")

        # Save GeoJSON
        filename = f"sp_{feature_id}.geojson"
        filepath = os.path.join(sp_path, filename)
        glacier_gdf.to_file(filepath, driver='GeoJSON')

        # Keep for next steps
        starting_points_df = glacier_gdf
        

        # === GENERATE FLOWLINES FROM SEEDING POINTS ===

        # Load vx
        with rasterio.open("data/kuba-flowlines/GL_vel_mosaic_Annual_01Dec15_30Nov21_vx_v05.0_nwcw_average.tif") as src_vx:
            Vx = src_vx.read(1)
            transform = src_vx.transform
            xres = transform.a
            yres = -transform.e  # usually negative
            width = src_vx.width
            height = src_vx.height

        # Load vy (assumed same grid)
        with rasterio.open("data/kuba-flowlines/GL_vel_mosaic_Annual_01Dec15_30Nov21_vy_v05.0_nwcw_average.tif") as src_vy:
            Vy = src_vy.read(1)

        # Load vv (assumed same grid)
        with rasterio.open("data/kuba-flowlines/GL_vel_mosaic_Annual_01Dec15_30Nov21_vv_v05.0_nwcw_average.tif") as src_vv:
            Vv = src_vv.read(1)

        # Reverse velocity for backward pathlines
        Vx = -Vx
        Vy = -Vy

        # Build coordinate arrays
        x = np.arange(width) * xres + transform.c
        y = np.arange(height) * -yres + transform.f  # careful: flip if needed

        pathlines = []
        metadata = []

        for idx, df in starting_points_df.iterrows():
            pt = df.geometry.coords[0]
            print(f" → Processing seed point {idx+1}/{len(starting_points_df)}: {pt}")
            glacier_id = df.get("glacier_ID", "unknown")
            feature_id = df.get("feature_ID", "unknown")

            try:
                pathline = compute_pathline(
                    [*pt],
                    velocity,
                    f_args=(Vx, Vy, x, y),
                    hmin=hmin,
                    hmax=hmax,
                    tol=tol,
                    start_time=start_time,
                    end_time=end_time,
                    v_threshold=v_threshold,
                    notebook=True,
                    progress=False,
                )
                pathlines.append(pathline)
                metadata.append(df.drop("geometry", errors="ignore"))

            except RuntimeError as e:
                print(f"Pathline failed for point {pt} feature_ID={feature_id}")
                print(f"   → Reason: {e}")


        # === SAVE FLOWLINES AS POINTS ===

        # Parameters
        fl_points_path = '/Users/jagon/Documents/Projects/Collabs/Jessica Badgeley/New Points v3/Output/Flowlines/as Points'
        os.makedirs(fl_points_path, exist_ok=True)

        # Generate result GeoDataFrame
        result = pd.concat(
            [
                series_to_pathline_geopandas_dataframe(
                    s.drop("geometry", errors="ignore"), pathlines[i]
                )
                for i, (k, s) in enumerate(starting_points_df.iterrows())
                if i < len(pathlines)
            ]
        ).reset_index(drop=True)

        # Filter out broken geometries
        result = result[
            (result.geometry.x > -700_000) & (result.geometry.x < 700_000) &
            (result.geometry.y > -3_000_000) & (result.geometry.y < -1_000_000)
        ]

        # Save GeoJSON
        filename = f"fl_{feature_id}_points.geojson"
        filepath = os.path.join(fl_points_path, filename)
        result.to_file(filepath, driver='GeoJSON')


        # === SAVE FLOWLINES AS CSV ===

        # Parameters
        fl_csv_path = '/Users/jagon/Documents/Projects/Collabs/Jessica Badgeley/New Points v3/Output/Flowlines/as CSV'
        os.makedirs(fl_csv_path, exist_ok=True)

        import warnings

        result_wkt = result.copy()

        with warnings.catch_warnings():
            warnings.simplefilter("ignore", UserWarning)
            result_wkt["geometry"] = result_wkt["geometry"].apply(lambda geom: geom.wkt)

        filename = f"fl_{feature_id}_points_v3.csv"
        filepath = os.path.join(fl_csv_path, filename)
        result_wkt.to_csv(filepath, index=False)


        # === SAVE FLOWLINES AS LINES ===

        # Parameters
        fl_lines_path = '/Users/jagon/Documents/Projects/Collabs/Jessica Badgeley/New Points v3/Output/Flowlines/as Lines'
        os.makedirs(fl_lines_path, exist_ok=True)

        result_lines = pd.concat(
                [
                    pathline_to_line_geopandas_dataframe(pathlines[k][0], attrs={"pathline_id": [k]})
                    for k, _ in starting_points_df.iterrows()
                ]
            ).reset_index(drop=True)

        # Filter out broken geometries
        result_lines = result_lines[
            (result_lines.geometry.bounds.minx > -700_000) & (result_lines.geometry.bounds.maxx < 700_000) &
            (result_lines.geometry.bounds.miny > -3_000_000) & (result_lines.geometry.bounds.maxy < -1_000_000)
        ]

        # Save GeoJSON
        filename = f"fl_{feature_id}_lines_v3.geojson"
        filepath = os.path.join(fl_lines_path, filename)
        result_lines.to_file(filepath, driver='GeoJSON')

        print(f"For Glacier {glacier_name} (ID:{feature_id}) generated {len(result_lines)} flowlines (with {len(result)} points).")
 

        # === GET FLOWLINES STATISTICS ===

        # Aggregate metrics
        summary = result.groupby("pathline_id").agg(
            v_sum=("v", "sum"),
            v_avg=("v", "mean"),
            num_points=("v", "count"),
            stopped_at_time=("time", "max"),
            mean_error=("error", "mean"),
            mean_distance=("distance", "mean")
        ).reset_index()

        # For stopped_at_distance, get last point per pathline
        last_points = result.sort_values("time").groupby("pathline_id").last().reset_index()
        last_points = last_points[["pathline_id", "distance_from_origin"]].rename(
            columns={"distance_from_origin": "stopped_at_distance"}
        )

        # Merge summary and last point info
        summary = pd.merge(summary, last_points, on="pathline_id")

        # Get metadata from the first point
        first_points = result.sort_values("time").groupby("pathline_id").first().reset_index()
        first_points = first_points.rename(columns={
            "x": "x_start",
            "y": "y_start"
        })

        meta_cols = ["pathline_id", "glacier_ID", "feature_ID", "glacier_name", "x_start", "y_start"]
        first_points = first_points[meta_cols]

        # Merge everything
        flowline_stats = pd.merge(first_points, summary, on="pathline_id")

        # Reorder columns as requested
        desired_order = [
            "pathline_id",
            "glacier_ID",
            "feature_ID",
            "glacier_name",
            "x_start",
            "y_start",
            "num_points",
            "v_sum",
            "v_avg",
            "mean_error",
            "mean_distance",
            "stopped_at_distance",
            "stopped_at_time"
        ]
        flowline_stats = flowline_stats[desired_order]

        # Output path
        stats_path = '/Users/jagon/Documents/Projects/Collabs/Jessica Badgeley/New Points v3/Output/Statistics/Flowlines'
        os.makedirs(stats_path, exist_ok=True)
        filename = f"stats_fl_{first_points['feature_ID'].iloc[0]}_v3.csv"
        filepath = os.path.join(stats_path, filename)

        # Save CSV
        flowline_stats.to_csv(filepath, index=False)
        print(f"For Glacier {glacier_name} (ID:{feature_id}) saved flowline statistics.")


        # === SAVE FASTEST FLOWLINES AS LINES ===

        # Identify pathline_ids with highest v_sum and v_mean
        max_sum_id = flowline_stats.sort_values("v_sum", ascending=False).iloc[0]["pathline_id"]
        max_avg_id = flowline_stats.sort_values("v_avg", ascending=False).iloc[0]["pathline_id"]

        # Create output directories if needed
        out_dir_sum = '/Users/jagon/Documents/Projects/Collabs/Jessica Badgeley/New Points v3/Output/Flowlines/Fastest Sum'
        os.makedirs(out_dir_sum, exist_ok=True)
        out_dir_avg = '/Users/jagon/Documents/Projects/Collabs/Jessica Badgeley/New Points v3/Output/Flowlines/Fastest Avg'
        os.makedirs(out_dir_avg, exist_ok=True)

        # Extract the corresponding line geometries
        line_max_sum = pathline_to_line_geopandas_dataframe(
            pathlines[max_sum_id][0], attrs={"pathline_id": [max_sum_id]}
        )
        line_max_avg = pathline_to_line_geopandas_dataframe(
            pathlines[max_avg_id][0], attrs={"pathline_id": [max_avg_id]}
        )

        # Save as GeoJSON
        filename_sum = f"fl_{feature_id}_lines_max_sum_v3.geojson"
        filepath_sum = os.path.join(out_dir_sum, filename_sum)
        line_max_sum.to_file(filepath_sum, driver='GeoJSON')

        filename_avg = f"fl_{feature_id}_lines_max_avg_v3.geojson"
        filepath_avg = os.path.join(out_dir_avg, filename_avg)
        line_max_avg.to_file(filepath_avg, driver='GeoJSON')


        # === SAVE PLOT WITH DOTS ===

        # Create output folder if not exists
        plot_points_path = '/Users/jagon/Documents/Projects/Collabs/Jessica Badgeley/New Points v3/Output/Graphs/with Points'
        os.makedirs(plot_points_path, exist_ok=True)

        # Compute square bounds
        minx, miny, maxx, maxy = result.total_bounds
        center_x = (minx + maxx) / 2
        center_y = (miny + maxy) / 2

        width = maxx - minx
        height = maxy - miny
        max_extent = max(width, height) / 2 + 5000  # buffer of 5 km on each side

        minx = center_x - max_extent
        maxx = center_x + max_extent
        miny = center_y - max_extent
        maxy = center_y + max_extent

        # Flip y and Vv if needed (raster is top-down)
        if y[0] > y[-1]:
            y = y[::-1]
            Vv = Vv[::-1, :]

        # Wrap into xarray DataArray
        Vv = xr.DataArray(Vv, coords=[("y", y), ("x", x)])
        Vv_crop = Vv.sel(x=slice(minx, maxx), y=slice(miny, maxy))

        # Compute ratio for correct aspect
        width = maxx - minx
        height = maxy - miny
        # Check for valid numbers
        if width > 0 and height > 0:
            ratio = height / width
        else:
            raise ValueError("Invalid bounds: cannot compute aspect ratio.")

        NWCW = gp.read_file('data/kuba-flowlines/NW-CW_Basins.shp')
        contour100m = gp.read_file('data/kuba-flowlines/contour_100masl_arcticdem_10m_v4.1_nwcw.shp')
        contour1500m = gp.read_file('data/kuba-flowlines/contour_1500masl_arcticdem_10m_v4.1_nwcw.shp')
        contour = gp.read_file('data/kuba-flowlines/contour_every100_arcticdem_10m_v4.1_nwcw.shp')

        fig, ax = plt.subplots(1, figsize=(12, 12))
        ax.set_aspect('equal', adjustable='box')

        # Background raster
        Vv_crop.plot(
            ax=ax,
            cmap="speed_colorblind",
            vmin=10,
            vmax=1500,
            zorder=1,
            cbar_kwargs={
                "shrink": 0.6,
                "label": r"velocity [m a$^{-1}$]",
                "pad": 0.02
            }
        )

        # Contours
        contour.plot(ax=ax, color="b", edgecolor="k", linewidth=0.25, zorder=2)
        contour100m.plot(ax=ax, color="b", edgecolor="k", linewidth=1, zorder=2)
        contour1500m.plot(ax=ax, color="b", edgecolor="k", linewidth=1, zorder=2)

        # NWCW outline (on top of contours)
        NWCW.plot(ax=ax, facecolor="none", edgecolor="g", linewidth=1, zorder=3)

        # Flowlines
        result.plot(ax=ax, color="w", edgecolor="k", linewidth=0.00, markersize = 0.5, zorder=4)

        # Starting points (on top)
        starting_points_df.plot(ax=ax, color="black", edgecolor="k", linewidth=0.01, markersize=0.5, zorder=5)

        # Labels
        ax.set_xlabel("x coordinate of projection [m]", fontsize=12)
        ax.set_ylabel("y coordinate of projection [m]", fontsize=12)
        ax.set_title(f"ID: {feature_id}, {glacier_name}", fontsize=16)

        plt.tight_layout()
        output_path = os.path.join(plot_points_path, f"fl_{feature_id}_points_v3.pdf")
        plt.savefig(output_path, format="pdf", bbox_inches="tight")
        plt.close(fig)


        # === SAVE PLOT WITH LINES ===

        # Create output folder if not exists
        plot_lines_path = '/Users/jagon/Documents/Projects/Collabs/Jessica Badgeley/New Points v3/Output/Graphs/with Lines'
        os.makedirs(plot_lines_path, exist_ok=True)

        # Compute square bounds
        minx, miny, maxx, maxy = result.total_bounds
        center_x = (minx + maxx) / 2
        center_y = (miny + maxy) / 2

        width = maxx - minx
        height = maxy - miny
        max_extent = max(width, height) / 2 + 5000  # buffer of 5 km on each side

        minx = center_x - max_extent
        maxx = center_x + max_extent
        miny = center_y - max_extent
        maxy = center_y + max_extent

        # Flip y and Vv if needed (raster is top-down)
        if y[0] > y[-1]:
            y = y[::-1]
            Vv = Vv[::-1, :]

        # Wrap into xarray DataArray
        Vv = xr.DataArray(Vv, coords=[("y", y), ("x", x)])

        Vv_crop = Vv.sel(x=slice(minx, maxx), y=slice(miny, maxy))

        # Compute ratio for correct aspect
        width = maxx - minx
        height = maxy - miny
        # Check for valid numbers
        if width > 0 and height > 0:
            ratio = height / width
        else:
            raise ValueError("Invalid bounds: cannot compute aspect ratio.")

        fig, ax = plt.subplots(1, figsize=(12, 12))
        ax.set_aspect('equal', adjustable='box')

        # Background raster
        Vv_crop.plot(
            ax=ax,
            cmap="speed_colorblind",
            vmin=10,
            vmax=1500,
            zorder=1,
            cbar_kwargs={
                "shrink": 0.6,
                "label": r"velocity [m a$^{-1}$]",
                "pad": 0.02
            }
        )

        # Contours
        contour.plot(ax=ax, color="b", edgecolor="k", linewidth=0.25, zorder=2)
        contour100m.plot(ax=ax, color="b", edgecolor="k", linewidth=1, zorder=2)
        contour1500m.plot(ax=ax, color="b", edgecolor="k", linewidth=1, zorder=2)

        # NWCW outline (on top of contours)
        NWCW.plot(ax=ax, facecolor="none", edgecolor="g", linewidth=1, zorder=3)

        # Flowlines
        result_lines.plot(ax=ax, color="w", edgecolor="k", linewidth=0.75, zorder=4)

        # Starting points (on top)
        starting_points_df.plot(ax=ax, color="black", edgecolor="k", linewidth=0.01, markersize=0.5, zorder=5)

        # Labels
        ax.set_xlabel("x coordinate of projection [m]", fontsize=12)
        ax.set_ylabel("y coordinate of projection [m]", fontsize=12)
        ax.set_title(f"ID: {feature_id}, {glacier_name}", fontsize=16)

        plt.tight_layout()
        output_path = os.path.join(plot_lines_path, f"fl_{feature_id}_lines_v3.pdf")
        plt.savefig(output_path, format="pdf", bbox_inches="tight")
        plt.close(fig)

        # === SAVE PLOT WITH LINES (WITH CHAD'S IDs) ===

        # Create output folder if not exists
        plot_lines_chad_path = '/Users/jagon/Documents/Projects/Collabs/Jessica Badgeley/New Points v3/Output/Graphs/with Lines Chad'
        os.makedirs(plot_lines_chad_path, exist_ok=True)

        # Compute square bounds
        minx, miny, maxx, maxy = result.total_bounds
        center_x = (minx + maxx) / 2
        center_y = (miny + maxy) / 2

        width = maxx - minx
        height = maxy - miny
        max_extent = max(width, height) / 2 + 5000  # buffer of 5 km on each side

        minx = center_x - max_extent
        maxx = center_x + max_extent
        miny = center_y - max_extent
        maxy = center_y + max_extent

        # Flip y and Vv if needed (raster is top-down)
        if y[0] > y[-1]:
            y = y[::-1]
            Vv = Vv[::-1, :]

        # Wrap into xarray DataArray
        Vv = xr.DataArray(Vv, coords=[("y", y), ("x", x)])

        Vv_crop = Vv.sel(x=slice(minx, maxx), y=slice(miny, maxy))

        # Compute ratio for correct aspect
        width = maxx - minx
        height = maxy - miny
        # Check for valid numbers
        if width > 0 and height > 0:
            ratio = height / width
        else:
            raise ValueError("Invalid bounds: cannot compute aspect ratio.")

        fig, ax = plt.subplots(1, figsize=(12, 12))
        ax.set_aspect('equal', adjustable='box')

        # Background raster
        Vv_crop.plot(
            ax=ax,
            cmap="speed_colorblind",
            vmin=10,
            vmax=1500,
            zorder=1,
            cbar_kwargs={
                "shrink": 0.6,
                "label": r"velocity [m a$^{-1}$]",
                "pad": 0.02
            }
        )

        # Contours
        contour.plot(ax=ax, color="b", edgecolor="k", linewidth=0.25, zorder=2)
        contour100m.plot(ax=ax, color="b", edgecolor="k", linewidth=1, zorder=2)
        contour1500m.plot(ax=ax, color="b", edgecolor="k", linewidth=1, zorder=2)

        # NWCW outline (on top of contours)
        NWCW.plot(ax=ax, facecolor="none", edgecolor="g", linewidth=1, zorder=3)

        # Flowlines
        result_lines.plot(ax=ax, color="w", edgecolor="k", linewidth=0.75, zorder=4)

        # Starting points (on top)
        starting_points_df.plot(ax=ax, color="black", edgecolor="k", linewidth=0.01, markersize=0.5, zorder=5)

        # Labels
        ax.set_xlabel("x coordinate of projection [m]", fontsize=12)
        ax.set_ylabel("y coordinate of projection [m]", fontsize=12)
        ax.set_title(f"ID: {feature_id + 1}, {glacier_name}", fontsize=16)

        plt.tight_layout()
        output_path = os.path.join(plot_lines_chad_path, f"fl_{feature_id}_lines_chad_v3.pdf")
        plt.savefig(output_path, format="pdf", bbox_inches="tight")
        plt.close(fig)

        print(f"For Glacier {glacier_name} (ID:{feature_id}) saved plots).") 

        # === COMPUTE AND SAVE GLACIER STATISTICS ===

        # Compute per-glacier statistics
        stats_row = {
            "glacier_ID": glacier_id,
            "feature_ID": feature_id,
            "glacier_name": glacier_name,
            "num_sp": len(starting_points_df),
            "num_fl": len(result_lines),
            "num_fl_points": len(result),
            "failed_flowlines": len(starting_points_df) - len(result_lines)
        }

        if not flowline_stats.empty:
            stats_row["fastest_fl_sum"] = flowline_stats.sort_values("v_sum", ascending=False).iloc[0]["pathline_id"]
            stats_row["fastest_fl_avg"] = flowline_stats.sort_values("v_avg", ascending=False).iloc[0]["pathline_id"]
            stats_row["longest_fl"] = flowline_stats.sort_values("stopped_at_distance", ascending=False).iloc[0]["pathline_id"]
        else:
            stats_row["fastest_fl_sum"] = None
            stats_row["fastest_fl_avg"] = None
            stats_row["longest_fl"] = None

        # Append to global stats list
        if "all_glacier_stats" not in globals():
            all_glacier_stats = []

        all_glacier_stats.append(stats_row) 


    except Exception as e:
        print(print(f"Failed processing Glacier {glacier_name} (ID: {feature_id}): {e}"))

stats_df = pd.DataFrame(all_glacier_stats)
stats_path = '/Users/jagon/Documents/Projects/Collabs/Jessica Badgeley/New Points v3/Output/Statistics/Glaciers'
os.makedirs(stats_path, exist_ok=True)
filepath = os.path.join(stats_path, "stats_gl_gl40_v3.csv")
stats_df.to_csv(filepath, index=False)

print(f"Saved all-glacier statistics.")
# Out:
# Processing glaciers:   0%|          | 0/1 [00:00<?, ?it/s]
# For Glacier Nordenskiöld (ID:40) generated 788 seeding points across 4 boxes.
#  → Processing seed point 1/788: (-382859.0, -1478867.0)
#  → Processing seed point 2/788: (-382859.0, -1478667.0)
#  → Processing seed point 3/788: (-382859.0, -1478467.0)
#  → Processing seed point 4/788: (-382859.0, -1478267.0)
#  → Processing seed point 5/788: (-382859.0, -1478067.0)
#  → Processing seed point 6/788: (-382859.0, -1477867.0)
#  → Processing seed point 7/788: (-382859.0, -1477667.0)
#  → Processing seed point 8/788: (-382859.0, -1477467.0)
#  → Processing seed point 9/788: (-382859.0, -1477267.0)
#  → Processing seed point 10/788: (-382659.0, -1478867.0)
#  → Processing seed point 11/788: (-382659.0, -1478667.0)
#  → Processing seed point 12/788: (-382659.0, -1478467.0)
#  → Processing seed point 13/788: (-382659.0, -1478267.0)
#  → Processing seed point 14/788: (-382659.0, -1478067.0)
#  → Processing seed point 15/788: (-382659.0, -1477867.0)
#  → Processing seed point 16/788: (-382659.0, -1477667.0)
#  → Processing seed point 17/788: (-382659.0, -1477467.0)
#  → Processing seed point 18/788: (-382659.0, -1477267.0)
#  → Processing seed point 19/788: (-382459.0, -1478867.0)
#  → Processing seed point 20/788: (-382459.0, -1478667.0)
#  → Processing seed point 21/788: (-382459.0, -1478467.0)
#  → Processing seed point 22/788: (-382459.0, -1478267.0)
#  → Processing seed point 23/788: (-382459.0, -1478067.0)
#  → Processing seed point 24/788: (-382459.0, -1477867.0)
#  → Processing seed point 25/788: (-382459.0, -1477667.0)
#  → Processing seed point 26/788: (-382459.0, -1477467.0)
#  → Processing seed point 27/788: (-382459.0, -1477267.0)
#  → Processing seed point 28/788: (-382259.0, -1478867.0)
#  → Processing seed point 29/788: (-382259.0, -1478667.0)
#  → Processing seed point 30/788: (-382259.0, -1478467.0)
#  → Processing seed point 31/788: (-382259.0, -1478267.0)
#  → Processing seed point 32/788: (-382259.0, -1478067.0)
#  → Processing seed point 33/788: (-382259.0, -1477867.0)
#  → Processing seed point 34/788: (-382259.0, -1477667.0)
#  → Processing seed point 35/788: (-382259.0, -1477467.0)
#  → Processing seed point 36/788: (-382259.0, -1477267.0)
#  → Processing seed point 37/788: (-381968.0, -1483315.0)
#  → Processing seed point 38/788: (-381968.0, -1483115.0)
#  → Processing seed point 39/788: (-381968.0, -1482915.0)
#  → Processing seed point 40/788: (-381968.0, -1482715.0)
#  → Processing seed point 41/788: (-381968.0, -1482515.0)
#  → Processing seed point 42/788: (-381968.0, -1482315.0)
#  → Processing seed point 43/788: (-381968.0, -1482115.0)
#  → Processing seed point 44/788: (-381968.0, -1481915.0)
#  → Processing seed point 45/788: (-381968.0, -1481715.0)
#  → Processing seed point 46/788: (-381968.0, -1481515.0)
#  → Processing seed point 47/788: (-381968.0, -1481315.0)
#  → Processing seed point 48/788: (-381968.0, -1481115.0)
#  → Processing seed point 49/788: (-381968.0, -1480915.0)
#  → Processing seed point 50/788: (-381968.0, -1480715.0)
#  → Processing seed point 51/788: (-381968.0, -1480515.0)
#  → Processing seed point 52/788: (-381968.0, -1480315.0)
#  → Processing seed point 53/788: (-381968.0, -1480115.0)
#  → Processing seed point 54/788: (-381768.0, -1483315.0)
#  → Processing seed point 55/788: (-381768.0, -1483115.0)
#  → Processing seed point 56/788: (-381768.0, -1482915.0)
#  → Processing seed point 57/788: (-381768.0, -1482715.0)
#  → Processing seed point 58/788: (-381768.0, -1482515.0)
#  → Processing seed point 59/788: (-381768.0, -1482315.0)
#  → Processing seed point 60/788: (-381768.0, -1482115.0)
#  → Processing seed point 61/788: (-381768.0, -1481915.0)
#  → Processing seed point 62/788: (-381768.0, -1481715.0)
#  → Processing seed point 63/788: (-381768.0, -1481515.0)
#  → Processing seed point 64/788: (-381768.0, -1481315.0)
#  → Processing seed point 65/788: (-381768.0, -1481115.0)
#  → Processing seed point 66/788: (-381768.0, -1480915.0)
#  → Processing seed point 67/788: (-381768.0, -1480715.0)
#  → Processing seed point 68/788: (-381768.0, -1480515.0)
#  → Processing seed point 69/788: (-381768.0, -1480315.0)
#  → Processing seed point 70/788: (-381768.0, -1480115.0)
#  → Processing seed point 71/788: (-381568.0, -1483315.0)
#  → Processing seed point 72/788: (-381568.0, -1483115.0)
#  → Processing seed point 73/788: (-381568.0, -1482915.0)
#  → Processing seed point 74/788: (-381568.0, -1482715.0)
#  → Processing seed point 75/788: (-381568.0, -1482515.0)
#  → Processing seed point 76/788: (-381568.0, -1482315.0)
#  → Processing seed point 77/788: (-381568.0, -1482115.0)
#  → Processing seed point 78/788: (-381568.0, -1481915.0)
#  → Processing seed point 79/788: (-381568.0, -1481715.0)
#  → Processing seed point 80/788: (-381568.0, -1481515.0)
#  → Processing seed point 81/788: (-381568.0, -1481315.0)
#  → Processing seed point 82/788: (-381568.0, -1481115.0)
#  → Processing seed point 83/788: (-381568.0, -1480915.0)
#  → Processing seed point 84/788: (-381568.0, -1480715.0)
#  → Processing seed point 85/788: (-381568.0, -1480515.0)
#  → Processing seed point 86/788: (-381568.0, -1480315.0)
#  → Processing seed point 87/788: (-381568.0, -1480115.0)
#  → Processing seed point 88/788: (-381368.0, -1483315.0)
#  → Processing seed point 89/788: (-381368.0, -1483115.0)
#  → Processing seed point 90/788: (-381368.0, -1482915.0)
#  → Processing seed point 91/788: (-381368.0, -1482715.0)
#  → Processing seed point 92/788: (-381368.0, -1482515.0)
#  → Processing seed point 93/788: (-381368.0, -1482315.0)
#  → Processing seed point 94/788: (-381368.0, -1482115.0)
#  → Processing seed point 95/788: (-381368.0, -1481915.0)
#  → Processing seed point 96/788: (-381368.0, -1481715.0)
#  → Processing seed point 97/788: (-381368.0, -1481515.0)
#  → Processing seed point 98/788: (-381368.0, -1481315.0)
#  → Processing seed point 99/788: (-381368.0, -1481115.0)
#  → Processing seed point 100/788: (-381368.0, -1480915.0)
#  → Processing seed point 101/788: (-381368.0, -1480715.0)
#  → Processing seed point 102/788: (-381368.0, -1480515.0)
#  → Processing seed point 103/788: (-381368.0, -1480315.0)
#  → Processing seed point 104/788: (-381368.0, -1480115.0)
#  → Processing seed point 105/788: (-381168.0, -1483315.0)
#  → Processing seed point 106/788: (-381168.0, -1483115.0)
#  → Processing seed point 107/788: (-381168.0, -1482915.0)
#  → Processing seed point 108/788: (-381168.0, -1482715.0)
#  → Processing seed point 109/788: (-381168.0, -1482515.0)
#  → Processing seed point 110/788: (-381168.0, -1482315.0)
#  → Processing seed point 111/788: (-381168.0, -1482115.0)
#  → Processing seed point 112/788: (-381168.0, -1481915.0)
#  → Processing seed point 113/788: (-381168.0, -1481715.0)
#  → Processing seed point 114/788: (-381168.0, -1481515.0)
#  → Processing seed point 115/788: (-381168.0, -1481315.0)
#  → Processing seed point 116/788: (-381168.0, -1481115.0)
#  → Processing seed point 117/788: (-381168.0, -1480915.0)
#  → Processing seed point 118/788: (-381168.0, -1480715.0)
#  → Processing seed point 119/788: (-381168.0, -1480515.0)
#  → Processing seed point 120/788: (-381168.0, -1480315.0)
#  → Processing seed point 121/788: (-381168.0, -1480115.0)
#  → Processing seed point 122/788: (-380968.0, -1483315.0)
#  → Processing seed point 123/788: (-380968.0, -1483115.0)
#  → Processing seed point 124/788: (-380968.0, -1482915.0)
#  → Processing seed point 125/788: (-380968.0, -1482715.0)
#  → Processing seed point 126/788: (-380968.0, -1482515.0)
#  → Processing seed point 127/788: (-380968.0, -1482315.0)
#  → Processing seed point 128/788: (-380968.0, -1482115.0)
#  → Processing seed point 129/788: (-380968.0, -1481915.0)
#  → Processing seed point 130/788: (-380968.0, -1481715.0)
#  → Processing seed point 131/788: (-380968.0, -1481515.0)
#  → Processing seed point 132/788: (-380968.0, -1481315.0)
#  → Processing seed point 133/788: (-380968.0, -1481115.0)
#  → Processing seed point 134/788: (-380968.0, -1480915.0)
#  → Processing seed point 135/788: (-380968.0, -1480715.0)
#  → Processing seed point 136/788: (-380968.0, -1480515.0)
#  → Processing seed point 137/788: (-380968.0, -1480315.0)
#  → Processing seed point 138/788: (-380968.0, -1480115.0)
#  → Processing seed point 139/788: (-378668.0, -1491732.0)
#  → Processing seed point 140/788: (-378668.0, -1491532.0)
#  → Processing seed point 141/788: (-378668.0, -1491332.0)
#  → Processing seed point 142/788: (-378668.0, -1491132.0)
#  → Processing seed point 143/788: (-378668.0, -1490932.0)
#  → Processing seed point 144/788: (-378668.0, -1490732.0)
#  → Processing seed point 145/788: (-378668.0, -1490532.0)
#  → Processing seed point 146/788: (-378668.0, -1490332.0)
#  → Processing seed point 147/788: (-378668.0, -1490132.0)
#  → Processing seed point 148/788: (-378668.0, -1489932.0)
#  → Processing seed point 149/788: (-378668.0, -1489732.0)
#  → Processing seed point 150/788: (-378668.0, -1489532.0)
#  → Processing seed point 151/788: (-378668.0, -1489332.0)
#  → Processing seed point 152/788: (-378468.0, -1491732.0)
#  → Processing seed point 153/788: (-378468.0, -1491532.0)
#  → Processing seed point 154/788: (-378468.0, -1491332.0)
#  → Processing seed point 155/788: (-378468.0, -1491132.0)
#  → Processing seed point 156/788: (-378468.0, -1490932.0)
#  → Processing seed point 157/788: (-378468.0, -1490732.0)
#  → Processing seed point 158/788: (-378468.0, -1490532.0)
#  → Processing seed point 159/788: (-378468.0, -1490332.0)
#  → Processing seed point 160/788: (-378468.0, -1490132.0)
#  → Processing seed point 161/788: (-378468.0, -1489932.0)
#  → Processing seed point 162/788: (-378468.0, -1489732.0)
#  → Processing seed point 163/788: (-378468.0, -1489532.0)
#  → Processing seed point 164/788: (-378468.0, -1489332.0)
#  → Processing seed point 165/788: (-378268.0, -1491732.0)
#  → Processing seed point 166/788: (-378268.0, -1491532.0)
#  → Processing seed point 167/788: (-378268.0, -1491332.0)
#  → Processing seed point 168/788: (-378268.0, -1491132.0)
#  → Processing seed point 169/788: (-378268.0, -1490932.0)
#  → Processing seed point 170/788: (-378268.0, -1490732.0)
#  → Processing seed point 171/788: (-378268.0, -1490532.0)
#  → Processing seed point 172/788: (-378268.0, -1490332.0)
#  → Processing seed point 173/788: (-378268.0, -1490132.0)
#  → Processing seed point 174/788: (-378268.0, -1489932.0)
#  → Processing seed point 175/788: (-378268.0, -1489732.0)
#  → Processing seed point 176/788: (-378268.0, -1489532.0)
#  → Processing seed point 177/788: (-378268.0, -1489332.0)
#  → Processing seed point 178/788: (-378068.0, -1491732.0)
#  → Processing seed point 179/788: (-378068.0, -1491532.0)
#  → Processing seed point 180/788: (-378068.0, -1491332.0)
#  → Processing seed point 181/788: (-378068.0, -1491132.0)
#  → Processing seed point 182/788: (-378068.0, -1490932.0)
#  → Processing seed point 183/788: (-378068.0, -1490732.0)
#  → Processing seed point 184/788: (-378068.0, -1490532.0)
#  → Processing seed point 185/788: (-378068.0, -1490332.0)
#  → Processing seed point 186/788: (-378068.0, -1490132.0)
#  → Processing seed point 187/788: (-378068.0, -1489932.0)
#  → Processing seed point 188/788: (-378068.0, -1489732.0)
#  → Processing seed point 189/788: (-378068.0, -1489532.0)
#  → Processing seed point 190/788: (-378068.0, -1489332.0)
#  → Processing seed point 191/788: (-377868.0, -1491732.0)
#  → Processing seed point 192/788: (-377868.0, -1491532.0)
#  → Processing seed point 193/788: (-377868.0, -1491332.0)
#  → Processing seed point 194/788: (-377868.0, -1491132.0)
#  → Processing seed point 195/788: (-377868.0, -1490932.0)
#  → Processing seed point 196/788: (-377868.0, -1490732.0)
#  → Processing seed point 197/788: (-377868.0, -1490532.0)
#  → Processing seed point 198/788: (-377868.0, -1490332.0)
#  → Processing seed point 199/788: (-377868.0, -1490132.0)
#  → Processing seed point 200/788: (-377868.0, -1489932.0)
#  → Processing seed point 201/788: (-377868.0, -1489732.0)
#  → Processing seed point 202/788: (-377868.0, -1489532.0)
#  → Processing seed point 203/788: (-377868.0, -1489332.0)
#  → Processing seed point 204/788: (-377668.0, -1491732.0)
#  → Processing seed point 205/788: (-377668.0, -1491532.0)
#  → Processing seed point 206/788: (-377668.0, -1491332.0)
#  → Processing seed point 207/788: (-377668.0, -1491132.0)
#  → Processing seed point 208/788: (-377668.0, -1490932.0)
#  → Processing seed point 209/788: (-377668.0, -1490732.0)
#  → Processing seed point 210/788: (-377668.0, -1490532.0)
#  → Processing seed point 211/788: (-377668.0, -1490332.0)
#  → Processing seed point 212/788: (-377668.0, -1490132.0)
#  → Processing seed point 213/788: (-377668.0, -1489932.0)
#  → Processing seed point 214/788: (-377668.0, -1489732.0)
#  → Processing seed point 215/788: (-377668.0, -1489532.0)
#  → Processing seed point 216/788: (-377668.0, -1489332.0)
#  → Processing seed point 217/788: (-377468.0, -1491732.0)
#  → Processing seed point 218/788: (-377468.0, -1491532.0)
#  → Processing seed point 219/788: (-377468.0, -1491332.0)
#  → Processing seed point 220/788: (-377468.0, -1491132.0)
#  → Processing seed point 221/788: (-377468.0, -1490932.0)
#  → Processing seed point 222/788: (-377468.0, -1490732.0)
#  → Processing seed point 223/788: (-377468.0, -1490532.0)
#  → Processing seed point 224/788: (-377468.0, -1490332.0)
#  → Processing seed point 225/788: (-377468.0, -1490132.0)
#  → Processing seed point 226/788: (-377468.0, -1489932.0)
#  → Processing seed point 227/788: (-377468.0, -1489732.0)
#  → Processing seed point 228/788: (-377468.0, -1489532.0)
#  → Processing seed point 229/788: (-377468.0, -1489332.0)
#  → Processing seed point 230/788: (-377268.0, -1491732.0)
#  → Processing seed point 231/788: (-377268.0, -1491532.0)
#  → Processing seed point 232/788: (-377268.0, -1491332.0)
#  → Processing seed point 233/788: (-377268.0, -1491132.0)
#  → Processing seed point 234/788: (-377268.0, -1490932.0)
#  → Processing seed point 235/788: (-377268.0, -1490732.0)
#  → Processing seed point 236/788: (-377268.0, -1490532.0)
#  → Processing seed point 237/788: (-377268.0, -1490332.0)
#  → Processing seed point 238/788: (-377268.0, -1490132.0)
#  → Processing seed point 239/788: (-377268.0, -1489932.0)
#  → Processing seed point 240/788: (-377268.0, -1489732.0)
#  → Processing seed point 241/788: (-377268.0, -1489532.0)
#  → Processing seed point 242/788: (-377268.0, -1489332.0)
#  → Processing seed point 243/788: (-377068.0, -1491732.0)
#  → Processing seed point 244/788: (-377068.0, -1491532.0)
#  → Processing seed point 245/788: (-377068.0, -1491332.0)
#  → Processing seed point 246/788: (-377068.0, -1491132.0)
#  → Processing seed point 247/788: (-377068.0, -1490932.0)
#  → Processing seed point 248/788: (-377068.0, -1490732.0)
#  → Processing seed point 249/788: (-377068.0, -1490532.0)
#  → Processing seed point 250/788: (-377068.0, -1490332.0)
#  → Processing seed point 251/788: (-377068.0, -1490132.0)
#  → Processing seed point 252/788: (-377068.0, -1489932.0)
#  → Processing seed point 253/788: (-377068.0, -1489732.0)
#  → Processing seed point 254/788: (-377068.0, -1489532.0)
#  → Processing seed point 255/788: (-377068.0, -1489332.0)
#  → Processing seed point 256/788: (-376868.0, -1491732.0)
#  → Processing seed point 257/788: (-376868.0, -1491532.0)
#  → Processing seed point 258/788: (-376868.0, -1491332.0)
#  → Processing seed point 259/788: (-376868.0, -1491132.0)
#  → Processing seed point 260/788: (-376868.0, -1490932.0)
#  → Processing seed point 261/788: (-376868.0, -1490732.0)
#  → Processing seed point 262/788: (-376868.0, -1490532.0)
#  → Processing seed point 263/788: (-376868.0, -1490332.0)
#  → Processing seed point 264/788: (-376868.0, -1490132.0)
#  → Processing seed point 265/788: (-376868.0, -1489932.0)
#  → Processing seed point 266/788: (-376868.0, -1489732.0)
#  → Processing seed point 267/788: (-376868.0, -1489532.0)
#  → Processing seed point 268/788: (-376868.0, -1489332.0)
#  → Processing seed point 269/788: (-376668.0, -1491732.0)
#  → Processing seed point 270/788: (-376668.0, -1491532.0)
#  → Processing seed point 271/788: (-376668.0, -1491332.0)
#  → Processing seed point 272/788: (-376668.0, -1491132.0)
#  → Processing seed point 273/788: (-376668.0, -1490932.0)
#  → Processing seed point 274/788: (-376668.0, -1490732.0)
#  → Processing seed point 275/788: (-376668.0, -1490532.0)
#  → Processing seed point 276/788: (-376668.0, -1490332.0)
#  → Processing seed point 277/788: (-376668.0, -1490132.0)
#  → Processing seed point 278/788: (-376668.0, -1489932.0)
#  → Processing seed point 279/788: (-376668.0, -1489732.0)
#  → Processing seed point 280/788: (-376668.0, -1489532.0)
#  → Processing seed point 281/788: (-376668.0, -1489332.0)
#  → Processing seed point 282/788: (-376468.0, -1491732.0)
#  → Processing seed point 283/788: (-376468.0, -1491532.0)
#  → Processing seed point 284/788: (-376468.0, -1491332.0)
#  → Processing seed point 285/788: (-376468.0, -1491132.0)
#  → Processing seed point 286/788: (-376468.0, -1490932.0)
#  → Processing seed point 287/788: (-376468.0, -1490732.0)
#  → Processing seed point 288/788: (-376468.0, -1490532.0)
#  → Processing seed point 289/788: (-376468.0, -1490332.0)
#  → Processing seed point 290/788: (-376468.0, -1490132.0)
#  → Processing seed point 291/788: (-376468.0, -1489932.0)
#  → Processing seed point 292/788: (-376468.0, -1489732.0)
#  → Processing seed point 293/788: (-376468.0, -1489532.0)
#  → Processing seed point 294/788: (-376468.0, -1489332.0)
#  → Processing seed point 295/788: (-376268.0, -1491732.0)
#  → Processing seed point 296/788: (-376268.0, -1491532.0)
#  → Processing seed point 297/788: (-376268.0, -1491332.0)
#  → Processing seed point 298/788: (-376268.0, -1491132.0)
#  → Processing seed point 299/788: (-376268.0, -1490932.0)
#  → Processing seed point 300/788: (-376268.0, -1490732.0)
#  → Processing seed point 301/788: (-376268.0, -1490532.0)
#  → Processing seed point 302/788: (-376268.0, -1490332.0)
#  → Processing seed point 303/788: (-376268.0, -1490132.0)
#  → Processing seed point 304/788: (-376268.0, -1489932.0)
#  → Processing seed point 305/788: (-376268.0, -1489732.0)
#  → Processing seed point 306/788: (-376268.0, -1489532.0)
#  → Processing seed point 307/788: (-376268.0, -1489332.0)
#  → Processing seed point 308/788: (-376068.0, -1491732.0)
#  → Processing seed point 309/788: (-376068.0, -1491532.0)
#  → Processing seed point 310/788: (-376068.0, -1491332.0)
#  → Processing seed point 311/788: (-376068.0, -1491132.0)
#  → Processing seed point 312/788: (-376068.0, -1490932.0)
#  → Processing seed point 313/788: (-376068.0, -1490732.0)
#  → Processing seed point 314/788: (-376068.0, -1490532.0)
#  → Processing seed point 315/788: (-376068.0, -1490332.0)
#  → Processing seed point 316/788: (-376068.0, -1490132.0)
#  → Processing seed point 317/788: (-376068.0, -1489932.0)
#  → Processing seed point 318/788: (-376068.0, -1489732.0)
#  → Processing seed point 319/788: (-376068.0, -1489532.0)
#  → Processing seed point 320/788: (-376068.0, -1489332.0)
#  → Processing seed point 321/788: (-375868.0, -1491732.0)
#  → Processing seed point 322/788: (-375868.0, -1491532.0)
#  → Processing seed point 323/788: (-375868.0, -1491332.0)
#  → Processing seed point 324/788: (-375868.0, -1491132.0)
#  → Processing seed point 325/788: (-375868.0, -1490932.0)
#  → Processing seed point 326/788: (-375868.0, -1490732.0)
#  → Processing seed point 327/788: (-375868.0, -1490532.0)
#  → Processing seed point 328/788: (-375868.0, -1490332.0)
#  → Processing seed point 329/788: (-375868.0, -1490132.0)
#  → Processing seed point 330/788: (-375868.0, -1489932.0)
#  → Processing seed point 331/788: (-375868.0, -1489732.0)
#  → Processing seed point 332/788: (-375868.0, -1489532.0)
#  → Processing seed point 333/788: (-375868.0, -1489332.0)
#  → Processing seed point 334/788: (-375668.0, -1491732.0)
#  → Processing seed point 335/788: (-375668.0, -1491532.0)
#  → Processing seed point 336/788: (-375668.0, -1491332.0)
#  → Processing seed point 337/788: (-375668.0, -1491132.0)
#  → Processing seed point 338/788: (-375668.0, -1490932.0)
#  → Processing seed point 339/788: (-375668.0, -1490732.0)
#  → Processing seed point 340/788: (-375668.0, -1490532.0)
#  → Processing seed point 341/788: (-375668.0, -1490332.0)
#  → Processing seed point 342/788: (-375668.0, -1490132.0)
#  → Processing seed point 343/788: (-375668.0, -1489932.0)
#  → Processing seed point 344/788: (-375668.0, -1489732.0)
#  → Processing seed point 345/788: (-375668.0, -1489532.0)
#  → Processing seed point 346/788: (-375668.0, -1489332.0)
#  → Processing seed point 347/788: (-375468.0, -1491732.0)
#  → Processing seed point 348/788: (-375468.0, -1491532.0)
#  → Processing seed point 349/788: (-375468.0, -1491332.0)
#  → Processing seed point 350/788: (-375468.0, -1491132.0)
#  → Processing seed point 351/788: (-375468.0, -1490932.0)
#  → Processing seed point 352/788: (-375468.0, -1490732.0)
#  → Processing seed point 353/788: (-375468.0, -1490532.0)
#  → Processing seed point 354/788: (-375468.0, -1490332.0)
#  → Processing seed point 355/788: (-375468.0, -1490132.0)
#  → Processing seed point 356/788: (-375468.0, -1489932.0)
#  → Processing seed point 357/788: (-375468.0, -1489732.0)
#  → Processing seed point 358/788: (-375468.0, -1489532.0)
#  → Processing seed point 359/788: (-375468.0, -1489332.0)
#  → Processing seed point 360/788: (-375268.0, -1491732.0)
#  → Processing seed point 361/788: (-375268.0, -1491532.0)
#  → Processing seed point 362/788: (-375268.0, -1491332.0)
#  → Processing seed point 363/788: (-375268.0, -1491132.0)
#  → Processing seed point 364/788: (-375268.0, -1490932.0)
#  → Processing seed point 365/788: (-375268.0, -1490732.0)
#  → Processing seed point 366/788: (-375268.0, -1490532.0)
#  → Processing seed point 367/788: (-375268.0, -1490332.0)
#  → Processing seed point 368/788: (-375268.0, -1490132.0)
#  → Processing seed point 369/788: (-375268.0, -1489932.0)
#  → Processing seed point 370/788: (-375268.0, -1489732.0)
#  → Processing seed point 371/788: (-375268.0, -1489532.0)
#  → Processing seed point 372/788: (-375268.0, -1489332.0)
#  → Processing seed point 373/788: (-375282.0, -1499807.0)
#  → Processing seed point 374/788: (-375282.0, -1499607.0)
#  → Processing seed point 375/788: (-375282.0, -1499407.0)
#  → Processing seed point 376/788: (-375282.0, -1499207.0)
#  → Processing seed point 377/788: (-375282.0, -1499007.0)
#  → Processing seed point 378/788: (-375282.0, -1498807.0)
#  → Processing seed point 379/788: (-375282.0, -1498607.0)
#  → Processing seed point 380/788: (-375282.0, -1498407.0)
#  → Processing seed point 381/788: (-375282.0, -1498207.0)
#  → Processing seed point 382/788: (-375282.0, -1498007.0)
#  → Processing seed point 383/788: (-375282.0, -1497807.0)
#  → Processing seed point 384/788: (-375282.0, -1497607.0)
#  → Processing seed point 385/788: (-375282.0, -1497407.0)
#  → Processing seed point 386/788: (-375282.0, -1497207.0)
#  → Processing seed point 387/788: (-375282.0, -1497007.0)
#  → Processing seed point 388/788: (-375282.0, -1496807.0)
#  → Processing seed point 389/788: (-375282.0, -1496607.0)
#  → Processing seed point 390/788: (-375282.0, -1496407.0)
#  → Processing seed point 391/788: (-375282.0, -1496207.0)
#  → Processing seed point 392/788: (-375282.0, -1496007.0)
#  → Processing seed point 393/788: (-375282.0, -1495807.0)
#  → Processing seed point 394/788: (-375282.0, -1495607.0)
#  → Processing seed point 395/788: (-375282.0, -1495407.0)
#  → Processing seed point 396/788: (-375282.0, -1495207.0)
#  → Processing seed point 397/788: (-375282.0, -1495007.0)
#  → Processing seed point 398/788: (-375282.0, -1494807.0)
#  → Processing seed point 399/788: (-375282.0, -1494607.0)
#  → Processing seed point 400/788: (-375282.0, -1494407.0)
#  → Processing seed point 401/788: (-375282.0, -1494207.0)
#  → Processing seed point 402/788: (-375282.0, -1494007.0)
#  → Processing seed point 403/788: (-375282.0, -1493807.0)
#  → Processing seed point 404/788: (-375282.0, -1493607.0)
#  → Processing seed point 405/788: (-375082.0, -1499807.0)
#  → Processing seed point 406/788: (-375082.0, -1499607.0)
#  → Processing seed point 407/788: (-375082.0, -1499407.0)
#  → Processing seed point 408/788: (-375082.0, -1499207.0)
#  → Processing seed point 409/788: (-375082.0, -1499007.0)
#  → Processing seed point 410/788: (-375082.0, -1498807.0)
#  → Processing seed point 411/788: (-375082.0, -1498607.0)
#  → Processing seed point 412/788: (-375082.0, -1498407.0)
#  → Processing seed point 413/788: (-375082.0, -1498207.0)
#  → Processing seed point 414/788: (-375082.0, -1498007.0)
#  → Processing seed point 415/788: (-375082.0, -1497807.0)
#  → Processing seed point 416/788: (-375082.0, -1497607.0)
#  → Processing seed point 417/788: (-375082.0, -1497407.0)
#  → Processing seed point 418/788: (-375082.0, -1497207.0)
#  → Processing seed point 419/788: (-375082.0, -1497007.0)
#  → Processing seed point 420/788: (-375082.0, -1496807.0)
#  → Processing seed point 421/788: (-375082.0, -1496607.0)
#  → Processing seed point 422/788: (-375082.0, -1496407.0)
#  → Processing seed point 423/788: (-375082.0, -1496207.0)
#  → Processing seed point 424/788: (-375082.0, -1496007.0)
#  → Processing seed point 425/788: (-375082.0, -1495807.0)
#  → Processing seed point 426/788: (-375082.0, -1495607.0)
#  → Processing seed point 427/788: (-375082.0, -1495407.0)
#  → Processing seed point 428/788: (-375082.0, -1495207.0)
#  → Processing seed point 429/788: (-375082.0, -1495007.0)
#  → Processing seed point 430/788: (-375082.0, -1494807.0)
#  → Processing seed point 431/788: (-375082.0, -1494607.0)
#  → Processing seed point 432/788: (-375082.0, -1494407.0)
#  → Processing seed point 433/788: (-375082.0, -1494207.0)
#  → Processing seed point 434/788: (-375082.0, -1494007.0)
#  → Processing seed point 435/788: (-375082.0, -1493807.0)
#  → Processing seed point 436/788: (-375082.0, -1493607.0)
#  → Processing seed point 437/788: (-374882.0, -1499807.0)
#  → Processing seed point 438/788: (-374882.0, -1499607.0)
#  → Processing seed point 439/788: (-374882.0, -1499407.0)
#  → Processing seed point 440/788: (-374882.0, -1499207.0)
#  → Processing seed point 441/788: (-374882.0, -1499007.0)
#  → Processing seed point 442/788: (-374882.0, -1498807.0)
#  → Processing seed point 443/788: (-374882.0, -1498607.0)
#  → Processing seed point 444/788: (-374882.0, -1498407.0)
#  → Processing seed point 445/788: (-374882.0, -1498207.0)
#  → Processing seed point 446/788: (-374882.0, -1498007.0)
#  → Processing seed point 447/788: (-374882.0, -1497807.0)
#  → Processing seed point 448/788: (-374882.0, -1497607.0)
#  → Processing seed point 449/788: (-374882.0, -1497407.0)
#  → Processing seed point 450/788: (-374882.0, -1497207.0)
#  → Processing seed point 451/788: (-374882.0, -1497007.0)
#  → Processing seed point 452/788: (-374882.0, -1496807.0)
#  → Processing seed point 453/788: (-374882.0, -1496607.0)
#  → Processing seed point 454/788: (-374882.0, -1496407.0)
#  → Processing seed point 455/788: (-374882.0, -1496207.0)
#  → Processing seed point 456/788: (-374882.0, -1496007.0)
#  → Processing seed point 457/788: (-374882.0, -1495807.0)
#  → Processing seed point 458/788: (-374882.0, -1495607.0)
#  → Processing seed point 459/788: (-374882.0, -1495407.0)
#  → Processing seed point 460/788: (-374882.0, -1495207.0)
#  → Processing seed point 461/788: (-374882.0, -1495007.0)
#  → Processing seed point 462/788: (-374882.0, -1494807.0)
#  → Processing seed point 463/788: (-374882.0, -1494607.0)
#  → Processing seed point 464/788: (-374882.0, -1494407.0)
#  → Processing seed point 465/788: (-374882.0, -1494207.0)
#  → Processing seed point 466/788: (-374882.0, -1494007.0)
#  → Processing seed point 467/788: (-374882.0, -1493807.0)
#  → Processing seed point 468/788: (-374882.0, -1493607.0)
#  → Processing seed point 469/788: (-374682.0, -1499807.0)
#  → Processing seed point 470/788: (-374682.0, -1499607.0)
#  → Processing seed point 471/788: (-374682.0, -1499407.0)
#  → Processing seed point 472/788: (-374682.0, -1499207.0)
#  → Processing seed point 473/788: (-374682.0, -1499007.0)
#  → Processing seed point 474/788: (-374682.0, -1498807.0)
#  → Processing seed point 475/788: (-374682.0, -1498607.0)
#  → Processing seed point 476/788: (-374682.0, -1498407.0)
#  → Processing seed point 477/788: (-374682.0, -1498207.0)
#  → Processing seed point 478/788: (-374682.0, -1498007.0)
#  → Processing seed point 479/788: (-374682.0, -1497807.0)
#  → Processing seed point 480/788: (-374682.0, -1497607.0)
#  → Processing seed point 481/788: (-374682.0, -1497407.0)
#  → Processing seed point 482/788: (-374682.0, -1497207.0)
#  → Processing seed point 483/788: (-374682.0, -1497007.0)
#  → Processing seed point 484/788: (-374682.0, -1496807.0)
#  → Processing seed point 485/788: (-374682.0, -1496607.0)
#  → Processing seed point 486/788: (-374682.0, -1496407.0)
#  → Processing seed point 487/788: (-374682.0, -1496207.0)
#  → Processing seed point 488/788: (-374682.0, -1496007.0)
#  → Processing seed point 489/788: (-374682.0, -1495807.0)
#  → Processing seed point 490/788: (-374682.0, -1495607.0)
#  → Processing seed point 491/788: (-374682.0, -1495407.0)
#  → Processing seed point 492/788: (-374682.0, -1495207.0)
#  → Processing seed point 493/788: (-374682.0, -1495007.0)
#  → Processing seed point 494/788: (-374682.0, -1494807.0)
#  → Processing seed point 495/788: (-374682.0, -1494607.0)
#  → Processing seed point 496/788: (-374682.0, -1494407.0)
#  → Processing seed point 497/788: (-374682.0, -1494207.0)
#  → Processing seed point 498/788: (-374682.0, -1494007.0)
#  → Processing seed point 499/788: (-374682.0, -1493807.0)
#  → Processing seed point 500/788: (-374682.0, -1493607.0)
#  → Processing seed point 501/788: (-374482.0, -1499807.0)
#  → Processing seed point 502/788: (-374482.0, -1499607.0)
#  → Processing seed point 503/788: (-374482.0, -1499407.0)
#  → Processing seed point 504/788: (-374482.0, -1499207.0)
#  → Processing seed point 505/788: (-374482.0, -1499007.0)
#  → Processing seed point 506/788: (-374482.0, -1498807.0)
#  → Processing seed point 507/788: (-374482.0, -1498607.0)
#  → Processing seed point 508/788: (-374482.0, -1498407.0)
#  → Processing seed point 509/788: (-374482.0, -1498207.0)
#  → Processing seed point 510/788: (-374482.0, -1498007.0)
#  → Processing seed point 511/788: (-374482.0, -1497807.0)
#  → Processing seed point 512/788: (-374482.0, -1497607.0)
#  → Processing seed point 513/788: (-374482.0, -1497407.0)
#  → Processing seed point 514/788: (-374482.0, -1497207.0)
#  → Processing seed point 515/788: (-374482.0, -1497007.0)
#  → Processing seed point 516/788: (-374482.0, -1496807.0)
#  → Processing seed point 517/788: (-374482.0, -1496607.0)
#  → Processing seed point 518/788: (-374482.0, -1496407.0)
#  → Processing seed point 519/788: (-374482.0, -1496207.0)
#  → Processing seed point 520/788: (-374482.0, -1496007.0)
#  → Processing seed point 521/788: (-374482.0, -1495807.0)
#  → Processing seed point 522/788: (-374482.0, -1495607.0)
#  → Processing seed point 523/788: (-374482.0, -1495407.0)
#  → Processing seed point 524/788: (-374482.0, -1495207.0)
#  → Processing seed point 525/788: (-374482.0, -1495007.0)
#  → Processing seed point 526/788: (-374482.0, -1494807.0)
#  → Processing seed point 527/788: (-374482.0, -1494607.0)
#  → Processing seed point 528/788: (-374482.0, -1494407.0)
#  → Processing seed point 529/788: (-374482.0, -1494207.0)
#  → Processing seed point 530/788: (-374482.0, -1494007.0)
#  → Processing seed point 531/788: (-374482.0, -1493807.0)
#  → Processing seed point 532/788: (-374482.0, -1493607.0)
#  → Processing seed point 533/788: (-374282.0, -1499807.0)
#  → Processing seed point 534/788: (-374282.0, -1499607.0)
#  → Processing seed point 535/788: (-374282.0, -1499407.0)
#  → Processing seed point 536/788: (-374282.0, -1499207.0)
#  → Processing seed point 537/788: (-374282.0, -1499007.0)
#  → Processing seed point 538/788: (-374282.0, -1498807.0)
#  → Processing seed point 539/788: (-374282.0, -1498607.0)
#  → Processing seed point 540/788: (-374282.0, -1498407.0)
#  → Processing seed point 541/788: (-374282.0, -1498207.0)
#  → Processing seed point 542/788: (-374282.0, -1498007.0)
#  → Processing seed point 543/788: (-374282.0, -1497807.0)
#  → Processing seed point 544/788: (-374282.0, -1497607.0)
#  → Processing seed point 545/788: (-374282.0, -1497407.0)
#  → Processing seed point 546/788: (-374282.0, -1497207.0)
#  → Processing seed point 547/788: (-374282.0, -1497007.0)
#  → Processing seed point 548/788: (-374282.0, -1496807.0)
#  → Processing seed point 549/788: (-374282.0, -1496607.0)
#  → Processing seed point 550/788: (-374282.0, -1496407.0)
#  → Processing seed point 551/788: (-374282.0, -1496207.0)
#  → Processing seed point 552/788: (-374282.0, -1496007.0)
#  → Processing seed point 553/788: (-374282.0, -1495807.0)
#  → Processing seed point 554/788: (-374282.0, -1495607.0)
#  → Processing seed point 555/788: (-374282.0, -1495407.0)
#  → Processing seed point 556/788: (-374282.0, -1495207.0)
#  → Processing seed point 557/788: (-374282.0, -1495007.0)
#  → Processing seed point 558/788: (-374282.0, -1494807.0)
#  → Processing seed point 559/788: (-374282.0, -1494607.0)
#  → Processing seed point 560/788: (-374282.0, -1494407.0)
#  → Processing seed point 561/788: (-374282.0, -1494207.0)
#  → Processing seed point 562/788: (-374282.0, -1494007.0)
#  → Processing seed point 563/788: (-374282.0, -1493807.0)
#  → Processing seed point 564/788: (-374282.0, -1493607.0)
#  → Processing seed point 565/788: (-374082.0, -1499807.0)
#  → Processing seed point 566/788: (-374082.0, -1499607.0)
#  → Processing seed point 567/788: (-374082.0, -1499407.0)
#  → Processing seed point 568/788: (-374082.0, -1499207.0)
#  → Processing seed point 569/788: (-374082.0, -1499007.0)
#  → Processing seed point 570/788: (-374082.0, -1498807.0)
#  → Processing seed point 571/788: (-374082.0, -1498607.0)
#  → Processing seed point 572/788: (-374082.0, -1498407.0)
#  → Processing seed point 573/788: (-374082.0, -1498207.0)
#  → Processing seed point 574/788: (-374082.0, -1498007.0)
#  → Processing seed point 575/788: (-374082.0, -1497807.0)
#  → Processing seed point 576/788: (-374082.0, -1497607.0)
#  → Processing seed point 577/788: (-374082.0, -1497407.0)
#  → Processing seed point 578/788: (-374082.0, -1497207.0)
#  → Processing seed point 579/788: (-374082.0, -1497007.0)
#  → Processing seed point 580/788: (-374082.0, -1496807.0)
#  → Processing seed point 581/788: (-374082.0, -1496607.0)
#  → Processing seed point 582/788: (-374082.0, -1496407.0)
#  → Processing seed point 583/788: (-374082.0, -1496207.0)
#  → Processing seed point 584/788: (-374082.0, -1496007.0)
#  → Processing seed point 585/788: (-374082.0, -1495807.0)
#  → Processing seed point 586/788: (-374082.0, -1495607.0)
#  → Processing seed point 587/788: (-374082.0, -1495407.0)
#  → Processing seed point 588/788: (-374082.0, -1495207.0)
#  → Processing seed point 589/788: (-374082.0, -1495007.0)
#  → Processing seed point 590/788: (-374082.0, -1494807.0)
#  → Processing seed point 591/788: (-374082.0, -1494607.0)
#  → Processing seed point 592/788: (-374082.0, -1494407.0)
#  → Processing seed point 593/788: (-374082.0, -1494207.0)
#  → Processing seed point 594/788: (-374082.0, -1494007.0)
#  → Processing seed point 595/788: (-374082.0, -1493807.0)
#  → Processing seed point 596/788: (-374082.0, -1493607.0)
#  → Processing seed point 597/788: (-373882.0, -1499807.0)
#  → Processing seed point 598/788: (-373882.0, -1499607.0)
#  → Processing seed point 599/788: (-373882.0, -1499407.0)
#  → Processing seed point 600/788: (-373882.0, -1499207.0)
#  → Processing seed point 601/788: (-373882.0, -1499007.0)
#  → Processing seed point 602/788: (-373882.0, -1498807.0)
#  → Processing seed point 603/788: (-373882.0, -1498607.0)
#  → Processing seed point 604/788: (-373882.0, -1498407.0)
#  → Processing seed point 605/788: (-373882.0, -1498207.0)
#  → Processing seed point 606/788: (-373882.0, -1498007.0)
#  → Processing seed point 607/788: (-373882.0, -1497807.0)
#  → Processing seed point 608/788: (-373882.0, -1497607.0)
#  → Processing seed point 609/788: (-373882.0, -1497407.0)
#  → Processing seed point 610/788: (-373882.0, -1497207.0)
#  → Processing seed point 611/788: (-373882.0, -1497007.0)
#  → Processing seed point 612/788: (-373882.0, -1496807.0)
#  → Processing seed point 613/788: (-373882.0, -1496607.0)
#  → Processing seed point 614/788: (-373882.0, -1496407.0)
#  → Processing seed point 615/788: (-373882.0, -1496207.0)
#  → Processing seed point 616/788: (-373882.0, -1496007.0)
#  → Processing seed point 617/788: (-373882.0, -1495807.0)
#  → Processing seed point 618/788: (-373882.0, -1495607.0)
#  → Processing seed point 619/788: (-373882.0, -1495407.0)
#  → Processing seed point 620/788: (-373882.0, -1495207.0)
#  → Processing seed point 621/788: (-373882.0, -1495007.0)
#  → Processing seed point 622/788: (-373882.0, -1494807.0)
#  → Processing seed point 623/788: (-373882.0, -1494607.0)
#  → Processing seed point 624/788: (-373882.0, -1494407.0)
#  → Processing seed point 625/788: (-373882.0, -1494207.0)
#  → Processing seed point 626/788: (-373882.0, -1494007.0)
#  → Processing seed point 627/788: (-373882.0, -1493807.0)
#  → Processing seed point 628/788: (-373882.0, -1493607.0)
#  → Processing seed point 629/788: (-373682.0, -1499807.0)
#  → Processing seed point 630/788: (-373682.0, -1499607.0)
#  → Processing seed point 631/788: (-373682.0, -1499407.0)
#  → Processing seed point 632/788: (-373682.0, -1499207.0)
#  → Processing seed point 633/788: (-373682.0, -1499007.0)
#  → Processing seed point 634/788: (-373682.0, -1498807.0)
#  → Processing seed point 635/788: (-373682.0, -1498607.0)
#  → Processing seed point 636/788: (-373682.0, -1498407.0)
#  → Processing seed point 637/788: (-373682.0, -1498207.0)
#  → Processing seed point 638/788: (-373682.0, -1498007.0)
#  → Processing seed point 639/788: (-373682.0, -1497807.0)
#  → Processing seed point 640/788: (-373682.0, -1497607.0)
#  → Processing seed point 641/788: (-373682.0, -1497407.0)
#  → Processing seed point 642/788: (-373682.0, -1497207.0)
#  → Processing seed point 643/788: (-373682.0, -1497007.0)
#  → Processing seed point 644/788: (-373682.0, -1496807.0)
#  → Processing seed point 645/788: (-373682.0, -1496607.0)
#  → Processing seed point 646/788: (-373682.0, -1496407.0)
#  → Processing seed point 647/788: (-373682.0, -1496207.0)
#  → Processing seed point 648/788: (-373682.0, -1496007.0)
#  → Processing seed point 649/788: (-373682.0, -1495807.0)
#  → Processing seed point 650/788: (-373682.0, -1495607.0)
#  → Processing seed point 651/788: (-373682.0, -1495407.0)
#  → Processing seed point 652/788: (-373682.0, -1495207.0)
#  → Processing seed point 653/788: (-373682.0, -1495007.0)
#  → Processing seed point 654/788: (-373682.0, -1494807.0)
#  → Processing seed point 655/788: (-373682.0, -1494607.0)
#  → Processing seed point 656/788: (-373682.0, -1494407.0)
#  → Processing seed point 657/788: (-373682.0, -1494207.0)
#  → Processing seed point 658/788: (-373682.0, -1494007.0)
#  → Processing seed point 659/788: (-373682.0, -1493807.0)
#  → Processing seed point 660/788: (-373682.0, -1493607.0)
#  → Processing seed point 661/788: (-373482.0, -1499807.0)
#  → Processing seed point 662/788: (-373482.0, -1499607.0)
#  → Processing seed point 663/788: (-373482.0, -1499407.0)
#  → Processing seed point 664/788: (-373482.0, -1499207.0)
#  → Processing seed point 665/788: (-373482.0, -1499007.0)
#  → Processing seed point 666/788: (-373482.0, -1498807.0)
#  → Processing seed point 667/788: (-373482.0, -1498607.0)
#  → Processing seed point 668/788: (-373482.0, -1498407.0)
#  → Processing seed point 669/788: (-373482.0, -1498207.0)
#  → Processing seed point 670/788: (-373482.0, -1498007.0)
#  → Processing seed point 671/788: (-373482.0, -1497807.0)
#  → Processing seed point 672/788: (-373482.0, -1497607.0)
#  → Processing seed point 673/788: (-373482.0, -1497407.0)
#  → Processing seed point 674/788: (-373482.0, -1497207.0)
#  → Processing seed point 675/788: (-373482.0, -1497007.0)
#  → Processing seed point 676/788: (-373482.0, -1496807.0)
#  → Processing seed point 677/788: (-373482.0, -1496607.0)
#  → Processing seed point 678/788: (-373482.0, -1496407.0)
#  → Processing seed point 679/788: (-373482.0, -1496207.0)
#  → Processing seed point 680/788: (-373482.0, -1496007.0)
#  → Processing seed point 681/788: (-373482.0, -1495807.0)
#  → Processing seed point 682/788: (-373482.0, -1495607.0)
#  → Processing seed point 683/788: (-373482.0, -1495407.0)
#  → Processing seed point 684/788: (-373482.0, -1495207.0)
#  → Processing seed point 685/788: (-373482.0, -1495007.0)
#  → Processing seed point 686/788: (-373482.0, -1494807.0)
#  → Processing seed point 687/788: (-373482.0, -1494607.0)
#  → Processing seed point 688/788: (-373482.0, -1494407.0)
#  → Processing seed point 689/788: (-373482.0, -1494207.0)
#  → Processing seed point 690/788: (-373482.0, -1494007.0)
#  → Processing seed point 691/788: (-373482.0, -1493807.0)
#  → Processing seed point 692/788: (-373482.0, -1493607.0)
#  → Processing seed point 693/788: (-373282.0, -1499807.0)
#  → Processing seed point 694/788: (-373282.0, -1499607.0)
#  → Processing seed point 695/788: (-373282.0, -1499407.0)
#  → Processing seed point 696/788: (-373282.0, -1499207.0)
#  → Processing seed point 697/788: (-373282.0, -1499007.0)
#  → Processing seed point 698/788: (-373282.0, -1498807.0)
#  → Processing seed point 699/788: (-373282.0, -1498607.0)
#  → Processing seed point 700/788: (-373282.0, -1498407.0)
#  → Processing seed point 701/788: (-373282.0, -1498207.0)
#  → Processing seed point 702/788: (-373282.0, -1498007.0)
#  → Processing seed point 703/788: (-373282.0, -1497807.0)
#  → Processing seed point 704/788: (-373282.0, -1497607.0)
#  → Processing seed point 705/788: (-373282.0, -1497407.0)
#  → Processing seed point 706/788: (-373282.0, -1497207.0)
#  → Processing seed point 707/788: (-373282.0, -1497007.0)
#  → Processing seed point 708/788: (-373282.0, -1496807.0)
#  → Processing seed point 709/788: (-373282.0, -1496607.0)
#  → Processing seed point 710/788: (-373282.0, -1496407.0)
#  → Processing seed point 711/788: (-373282.0, -1496207.0)
#  → Processing seed point 712/788: (-373282.0, -1496007.0)
#  → Processing seed point 713/788: (-373282.0, -1495807.0)
#  → Processing seed point 714/788: (-373282.0, -1495607.0)
#  → Processing seed point 715/788: (-373282.0, -1495407.0)
#  → Processing seed point 716/788: (-373282.0, -1495207.0)
#  → Processing seed point 717/788: (-373282.0, -1495007.0)
#  → Processing seed point 718/788: (-373282.0, -1494807.0)
#  → Processing seed point 719/788: (-373282.0, -1494607.0)
#  → Processing seed point 720/788: (-373282.0, -1494407.0)
#  → Processing seed point 721/788: (-373282.0, -1494207.0)
#  → Processing seed point 722/788: (-373282.0, -1494007.0)
#  → Processing seed point 723/788: (-373282.0, -1493807.0)
#  → Processing seed point 724/788: (-373282.0, -1493607.0)
#  → Processing seed point 725/788: (-373082.0, -1499807.0)
#  → Processing seed point 726/788: (-373082.0, -1499607.0)
#  → Processing seed point 727/788: (-373082.0, -1499407.0)
#  → Processing seed point 728/788: (-373082.0, -1499207.0)
#  → Processing seed point 729/788: (-373082.0, -1499007.0)
#  → Processing seed point 730/788: (-373082.0, -1498807.0)
#  → Processing seed point 731/788: (-373082.0, -1498607.0)
#  → Processing seed point 732/788: (-373082.0, -1498407.0)
#  → Processing seed point 733/788: (-373082.0, -1498207.0)
#  → Processing seed point 734/788: (-373082.0, -1498007.0)
#  → Processing seed point 735/788: (-373082.0, -1497807.0)
#  → Processing seed point 736/788: (-373082.0, -1497607.0)
#  → Processing seed point 737/788: (-373082.0, -1497407.0)
#  → Processing seed point 738/788: (-373082.0, -1497207.0)
#  → Processing seed point 739/788: (-373082.0, -1497007.0)
#  → Processing seed point 740/788: (-373082.0, -1496807.0)
#  → Processing seed point 741/788: (-373082.0, -1496607.0)
#  → Processing seed point 742/788: (-373082.0, -1496407.0)
#  → Processing seed point 743/788: (-373082.0, -1496207.0)
#  → Processing seed point 744/788: (-373082.0, -1496007.0)
#  → Processing seed point 745/788: (-373082.0, -1495807.0)
#  → Processing seed point 746/788: (-373082.0, -1495607.0)
#  → Processing seed point 747/788: (-373082.0, -1495407.0)
#  → Processing seed point 748/788: (-373082.0, -1495207.0)
#  → Processing seed point 749/788: (-373082.0, -1495007.0)
#  → Processing seed point 750/788: (-373082.0, -1494807.0)
#  → Processing seed point 751/788: (-373082.0, -1494607.0)
#  → Processing seed point 752/788: (-373082.0, -1494407.0)
#  → Processing seed point 753/788: (-373082.0, -1494207.0)
#  → Processing seed point 754/788: (-373082.0, -1494007.0)
#  → Processing seed point 755/788: (-373082.0, -1493807.0)
#  → Processing seed point 756/788: (-373082.0, -1493607.0)
#  → Processing seed point 757/788: (-372882.0, -1499807.0)
#  → Processing seed point 758/788: (-372882.0, -1499607.0)
#  → Processing seed point 759/788: (-372882.0, -1499407.0)
#  → Processing seed point 760/788: (-372882.0, -1499207.0)
#  → Processing seed point 761/788: (-372882.0, -1499007.0)
#  → Processing seed point 762/788: (-372882.0, -1498807.0)
#  → Processing seed point 763/788: (-372882.0, -1498607.0)
#  → Processing seed point 764/788: (-372882.0, -1498407.0)
#  → Processing seed point 765/788: (-372882.0, -1498207.0)
#  → Processing seed point 766/788: (-372882.0, -1498007.0)
#  → Processing seed point 767/788: (-372882.0, -1497807.0)
#  → Processing seed point 768/788: (-372882.0, -1497607.0)
#  → Processing seed point 769/788: (-372882.0, -1497407.0)
#  → Processing seed point 770/788: (-372882.0, -1497207.0)
#  → Processing seed point 771/788: (-372882.0, -1497007.0)
#  → Processing seed point 772/788: (-372882.0, -1496807.0)
#  → Processing seed point 773/788: (-372882.0, -1496607.0)
#  → Processing seed point 774/788: (-372882.0, -1496407.0)
#  → Processing seed point 775/788: (-372882.0, -1496207.0)
#  → Processing seed point 776/788: (-372882.0, -1496007.0)
#  → Processing seed point 777/788: (-372882.0, -1495807.0)
#  → Processing seed point 778/788: (-372882.0, -1495607.0)
#  → Processing seed point 779/788: (-372882.0, -1495407.0)
#  → Processing seed point 780/788: (-372882.0, -1495207.0)
#  → Processing seed point 781/788: (-372882.0, -1495007.0)
#  → Processing seed point 782/788: (-372882.0, -1494807.0)
#  → Processing seed point 783/788: (-372882.0, -1494607.0)
#  → Processing seed point 784/788: (-372882.0, -1494407.0)
#  → Processing seed point 785/788: (-372882.0, -1494207.0)
#  → Processing seed point 786/788: (-372882.0, -1494007.0)
#  → Processing seed point 787/788: (-372882.0, -1493807.0)
#  → Processing seed point 788/788: (-372882.0, -1493607.0)
# For Glacier Nordenskiöld (ID:40) generated 329 flowlines (with 133305 points).
# For Glacier Nordenskiöld (ID:40) saved flowline statistics.
# Processing glaciers: 100%|██████████| 1/1 [03:52<00:00, 232.91s/it]
# For Glacier Nordenskiöld (ID:40) saved plots).
# Saved all-glacier statistics.

# %%
result
# Out:
#                               geometry  glacier_ID  feature_ID glacier_name  \
# 0     POINT (-587999.000 -1172698.000)           1         173    Diebitsch
# 1     POINT (-587999.000 -1172448.000)           1         173    Diebitsch
# 2     POINT (-587999.000 -1172198.000)           1         173    Diebitsch
# 3     POINT (-587999.000 -1171948.000)           1         173    Diebitsch
# 4     POINT (-587999.000 -1171698.000)           1         173    Diebitsch
# ...                                ...         ...         ...          ...
# 4892  POINT (-581624.731 -1171038.887)           1         173    Diebitsch
# 4893  POINT (-585249.000 -1169948.000)           1         173    Diebitsch
# 4894  POINT (-585249.000 -1169948.000)           1         173    Diebitsch
# 4895  POINT (-585140.033 -1169872.850)           1         173    Diebitsch
# 4896  POINT (-585046.998 -1169806.964)           1         173    Diebitsch
#
#      box_number       x        y          vx         vy           v  \
# 0             1 -587999 -1172698         NaN        NaN         NaN
# 1             1 -587999 -1172448         NaN        NaN         NaN
# 2             1 -587999 -1172198         NaN        NaN         NaN
# 3             1 -587999 -1171948         NaN        NaN         NaN
# 4             1 -587999 -1171698         NaN        NaN         NaN
# ...         ...     ...      ...         ...        ...         ...
# 4892          1 -585249 -1170198  102.250677  -7.640015  102.535705
# 4893          1 -585249 -1169948  117.983687  80.879834  143.044392
# 4894          1 -585249 -1169948  117.983687  80.879834  143.044392
# 4895          1 -585249 -1169948  100.545167  70.091318  122.564773
# 4896          1 -585249 -1169948   85.768427  61.672569  105.639618
#
#       pathline_id    distance  distance_from_origin  time     error
# 0               0    0.000000              0.000000   0.0  0.000000
# 1               1    0.000000              0.000000   0.0  0.000000
# 2               2    0.000000              0.000000   0.0  0.000000
# 3               3    0.000000              0.000000   0.0  0.000000
# 4               4    0.000000              0.000000   0.0  0.000000
# ...           ...         ...                   ...   ...       ...
# 4892          142  105.461085           3855.157824  32.0  0.000021
# 4893          143    0.000000              0.000000   0.0  0.000000
# 4894          143    0.000000              0.000000   0.0  0.004286
# 4895          143  132.367921            132.367921   1.0  0.000206
# 4896          143  114.002825            246.370746   2.0  0.000145
#
# [4897 rows x 15 columns]

# %% [markdown]
# Picked Flowlines Extraction

# %%
import os
import pandas as pd
import geopandas as gpd

# Input paths
picks_csv_path = '/Users/jagon/Documents/Projects/Collabs/Jessica Badgeley/New Points v3/Flowlines of Interest/fl_picks_3.1.csv'
flowlines_dir = '/Users/jagon/Documents/Projects/Collabs/Jessica Badgeley/New Points v3/Output/Flowlines/as Lines'
output_dir = '/Users/jagon/Documents/Projects/Collabs/Jessica Badgeley/New Points v3/Flowlines of Interest/Picks'
os.makedirs(output_dir, exist_ok=True)

# Load picks CSV
picks_df = pd.read_csv(picks_csv_path)

# Iterate over each row (each glacier/feature_ID)
for _, row in picks_df.iterrows():
    feature_id = row['feature_ID']
    flowline_file = os.path.join(flowlines_dir, f"fl_{feature_id}_lines_v3.geojson")

    if not os.path.exists(flowline_file):
        print(f"⚠️ Flowline file missing: {flowline_file}")
        continue

    # Load flowlines for current feature_ID
    gdf = gpd.read_file(flowline_file)

    # Check all pathline_id columns (pathline_id_1, pathline_id_2, ...)
    for col in row.index:
        if col.startswith("pathline_id_") and pd.notna(row[col]):
            pathline_id = int(row[col])
            flowline_number = col.split("_")[-1]  # e.g., '1', '2', etc.

            # Filter flowline with specific pathline_id
            subset = gdf[gdf['pathline_id'] == pathline_id]
            if subset.empty:
                print(f"Pathline_id {pathline_id} not found in fl_{feature_id}_lines_v3.geojson")
                continue

            # Save each selected flowline as separate GeoJSON
            out_name = f"gl_{feature_id}_{flowline_number}.geojson"
            out_path = os.path.join(output_dir, out_name)
            subset.to_file(out_path, driver='GeoJSON')
            print(f"Saved: {out_name}")
# Out:
# ✅ Saved: gl_173_1.geojson
# ✅ Saved: gl_173_2.geojson
# ✅ Saved: gl_171_1.geojson
# ✅ Saved: gl_166_1.geojson
# ✅ Saved: gl_166_2.geojson
# ✅ Saved: gl_163_1.geojson
# ✅ Saved: gl_159_1.geojson
# ✅ Saved: gl_104_1.geojson
# ✅ Saved: gl_103_1.geojson
# ✅ Saved: gl_103_2.geojson
# ✅ Saved: gl_103_3.geojson
# ✅ Saved: gl_102_1.geojson
# ✅ Saved: gl_47_1.geojson
# ✅ Saved: gl_47_2.geojson
# ✅ Saved: gl_47_3.geojson
# ✅ Saved: gl_47_4.geojson
# ✅ Saved: gl_46_1.geojson
# ✅ Saved: gl_46_2.geojson
# ✅ Saved: gl_45_1.geojson
# ✅ Saved: gl_48_1.geojson
# ✅ Saved: gl_48_2.geojson
# ✅ Saved: gl_182_1.geojson
# ✅ Saved: gl_182_2.geojson
# ✅ Saved: gl_182_3.geojson
# ✅ Saved: gl_241_1.geojson
# ✅ Saved: gl_239_1.geojson
# ✅ Saved: gl_239_2.geojson
# ✅ Saved: gl_238_1.geojson
# ✅ Saved: gl_184_1.geojson
# ✅ Saved: gl_184_2.geojson
# ✅ Saved: gl_195_1.geojson
# ✅ Saved: gl_194_1.geojson
# ✅ Saved: gl_196_1.geojson
# ✅ Saved: gl_44_1.geojson
# ✅ Saved: gl_44_2.geojson
# ✅ Saved: gl_146_1.geojson
# ✅ Saved: gl_146_2.geojson
# ✅ Saved: gl_146_3.geojson
# ✅ Saved: gl_146_4.geojson
# ✅ Saved: gl_146_5.geojson
# ✅ Saved: gl_146_6.geojson
# ✅ Saved: gl_147_1.geojson
# ✅ Saved: gl_147_2.geojson
# ✅ Saved: gl_77_1.geojson
# ✅ Saved: gl_77_2.geojson
# ✅ Saved: gl_43_1.geojson
# ✅ Saved: gl_43_2.geojson
# ✅ Saved: gl_43_3.geojson
# ✅ Saved: gl_42_1.geojson
# ✅ Saved: gl_42_2.geojson
# ✅ Saved: gl_41_1.geojson
# ✅ Saved: gl_41_2.geojson
# ✅ Saved: gl_126_1.geojson
# ✅ Saved: gl_126_2.geojson
# ✅ Saved: gl_126_3.geojson
# ✅ Saved: gl_40_1.geojson
# ✅ Saved: gl_40_2.geojson
# ✅ Saved: gl_40_3.geojson
# ✅ Saved: gl_36_1.geojson
# ✅ Saved: gl_36_2.geojson
# ✅ Saved: gl_36_3.geojson
# ✅ Saved: gl_35_1.geojson
# ✅ Saved: gl_35_2.geojson
# ✅ Saved: gl_35_3.geojson
# ✅ Saved: gl_35_4.geojson
# ✅ Saved: gl_37_1.geojson
# ✅ Saved: gl_37_2.geojson
# ✅ Saved: gl_37_3.geojson
# ✅ Saved: gl_34_1.geojson
# ✅ Saved: gl_34_2.geojson
# ✅ Saved: gl_34_3.geojson
# ✅ Saved: gl_213_1.geojson
# ✅ Saved: gl_213_2.geojson
# ✅ Saved: gl_213_3.geojson
# ✅ Saved: gl_213_4.geojson
# ✅ Saved: gl_33_1.geojson
# ✅ Saved: gl_33_2.geojson
# ✅ Saved: gl_33_3.geojson
# ✅ Saved: gl_32_1.geojson
# ✅ Saved: gl_32_2.geojson
# ✅ Saved: gl_31_1.geojson
# ✅ Saved: gl_31_2.geojson
# ✅ Saved: gl_31_3.geojson
# ✅ Saved: gl_30_1.geojson
# ✅ Saved: gl_30_2.geojson
# ✅ Saved: gl_29_1.geojson
# ✅ Saved: gl_29_2.geojson
# ✅ Saved: gl_28_1.geojson
# ✅ Saved: gl_28_2.geojson
# ✅ Saved: gl_28_3.geojson
# ✅ Saved: gl_27_1.geojson
# ✅ Saved: gl_27_2.geojson
# ✅ Saved: gl_26_1.geojson
# ✅ Saved: gl_26_2.geojson
# ✅ Saved: gl_26_3.geojson
# ✅ Saved: gl_25_1.geojson
# ✅ Saved: gl_85_1.geojson
# ✅ Saved: gl_85_2.geojson
# ✅ Saved: gl_206_1.geojson
# ✅ Saved: gl_207_1.geojson
# ✅ Saved: gl_207_2.geojson
# ✅ Saved: gl_24_1.geojson
# ✅ Saved: gl_22_1.geojson
# ✅ Saved: gl_0_1.geojson
# ✅ Saved: gl_2_1.geojson
# ✅ Saved: gl_2_2.geojson
# ✅ Saved: gl_2_3.geojson
# ✅ Saved: gl_3_1.geojson
# ✅ Saved: gl_84_1.geojson
# ✅ Saved: gl_5_1.geojson
# ✅ Saved: gl_5_2.geojson
# ✅ Saved: gl_5_3.geojson
# ✅ Saved: gl_6_1.geojson
# ✅ Saved: gl_7_1.geojson
# ✅ Saved: gl_7_2.geojson
# ✅ Saved: gl_8_1.geojson
# ✅ Saved: gl_8_2.geojson
# ✅ Saved: gl_8_3.geojson
# ✅ Saved: gl_9_1.geojson
# ✅ Saved: gl_9_2.geojson
# ✅ Saved: gl_80_1.geojson
# ✅ Saved: gl_80_2.geojson
# ✅ Saved: gl_81_1.geojson
# ✅ Saved: gl_71_1.geojson
# ✅ Saved: gl_221_1.geojson
# ✅ Saved: gl_217_1.geojson
# ✅ Saved: gl_217_2.geojson
# ✅ Saved: gl_217_3.geojson
# ✅ Saved: gl_217_4.geojson
# ✅ Saved: gl_217_5.geojson
# ✅ Saved: gl_217_6.geojson
# ✅ Saved: gl_217_7.geojson
# ✅ Saved: gl_218_1.geojson
# ✅ Saved: gl_218_2.geojson

# %% [markdown]
# Flowline Graphs with Picked Flowlines

# %%
import os
import geopandas as gp
import pandas as pd
import matplotlib.pyplot as plt
import xarray as xr
import rasterio

# === Paths ===
all_fl_path = '/Users/jagon/Documents/Projects/Collabs/Jessica Badgeley/New Points v3/Output/Flowlines/as Lines'
picked_fl_path = '/Users/jagon/Documents/Projects/Collabs/Jessica Badgeley/New Points v3/Flowlines of Interest/Picks'
sp_path = '/Users/jagon/Documents/Projects/Collabs/Jessica Badgeley/New Points v3/Input/Starting Points'
out_path = '/Users/jagon/Documents/Projects/Collabs/Jessica Badgeley/New Points v3/Flowlines of Interest/Graphs with Picks/with Lines'
out_chad_path = '/Users/jagon/Documents/Projects/Collabs/Jessica Badgeley/New Points v3/Flowlines of Interest/Graphs with Picks/with Lines Chad'
titles_csv = '/Users/jagon/Documents/Projects/Collabs/Jessica Badgeley/New Points v3/Flowlines of Interest/fl_picks_3.1.csv'

os.makedirs(out_path, exist_ok=True)
os.makedirs(out_chad_path, exist_ok=True)

# === Static overlays ===
NWCW = gp.read_file('data/kuba-flowlines/NW-CW_Basins.shp')
contour100m = gp.read_file('data/kuba-flowlines/contour_100masl_arcticdem_10m_v4.1_nwcw.shp')
contour1500m = gp.read_file('data/kuba-flowlines/contour_1500masl_arcticdem_10m_v4.1_nwcw.shp')
contour = gp.read_file('data/kuba-flowlines/contour_every100_arcticdem_10m_v4.1_nwcw.shp')

# === Raster ===
with rasterio.open("data/kuba-flowlines/GL_vel_mosaic_Annual_01Dec15_30Nov21_vv_v05.0_nwcw_average.tif") as src_vv:
    Vv = src_vv.read(1)
    transform = src_vv.transform
    x = (np.arange(src_vv.width) * transform.a) + transform.c
    y = (np.arange(src_vv.height) * transform.e) + transform.f

if y[0] > y[-1]:
    y = y[::-1]
    Vv = Vv[::-1, :]

Vv = xr.DataArray(Vv, coords=[("y", y), ("x", x)])

# === Metadata ===
titles_df = pd.read_csv(titles_csv)

# === Loop ===
for _, row in titles_df.iterrows():
    feature_id = int(row["feature_ID"])
    glacier_name = row["glacier_name"]

    try:
        fl_file = f"fl_{feature_id}_lines_v3.geojson"
        all_fl = gp.read_file(os.path.join(all_fl_path, fl_file))

        sp_file = f"sp_{feature_id}.geojson"
        starting_points_df = gp.read_file(os.path.join(sp_path, sp_file))

        picks = []
        for fname in os.listdir(picked_fl_path):
            if fname.startswith(f"gl_{feature_id}_") and fname.endswith(".geojson"):
                picks.append(gp.read_file(os.path.join(picked_fl_path, fname)))

        if not picks:
            print(f"No picks found for glacier {feature_id}. Skipping plot.")
            continue

        picks_gdf = pd.concat(picks).reset_index(drop=True)

        # Bounds
        minx, miny, maxx, maxy = all_fl.total_bounds
        center_x = (minx + maxx) / 2
        center_y = (miny + maxy) / 2
        width = maxx - minx
        height = maxy - miny
        max_extent = max(width, height) / 2 + 5000
        minx = center_x - max_extent
        maxx = center_x + max_extent
        miny = center_y - max_extent
        maxy = center_y + max_extent

        Vv_crop = Vv.sel(x=slice(minx, maxx), y=slice(miny, maxy))

        for suffix, title_id, out_dir in [("", feature_id, out_path), ("_chad", feature_id + 1, out_chad_path)]:
            fig, ax = plt.subplots(1, figsize=(12, 12))
            ax.set_aspect('equal', adjustable='box')

            Vv_crop.plot(
                ax=ax,
                cmap="speed_colorblind",
                vmin=10,
                vmax=1500,
                zorder=1,
                cbar_kwargs={"shrink": 0.6, "label": r"velocity [m a$^{-1}$]", "pad": 0.02}
            )

            contour.plot(ax=ax, color="b", edgecolor="k", linewidth=0.25, zorder=2)
            contour100m.plot(ax=ax, color="b", edgecolor="k", linewidth=1, zorder=2)
            contour1500m.plot(ax=ax, color="b", edgecolor="k", linewidth=1, zorder=2)
            NWCW.plot(ax=ax, facecolor="none", edgecolor="g", linewidth=1, zorder=3)
            all_fl.plot(ax=ax, color="w", edgecolor="k", linewidth=0.75, zorder=4)
            picks_gdf.plot(ax=ax, color="black", edgecolor="k", linewidth=2.5, zorder=5)
            starting_points_df.plot(ax=ax, color="black", edgecolor="k", linewidth=0.01, markersize=0.5, zorder=6)

            ax.set_xlabel("x coordinate of projection [m]", fontsize=12)
            ax.set_ylabel("y coordinate of projection [m]", fontsize=12)
            ax.set_title(f"ID: {title_id}, {glacier_name}", fontsize=16)

            plt.tight_layout()
            filename = f"fl_{feature_id}_picked_lines{suffix}_v3.pdf"
            output_path = os.path.join(out_dir, filename)
            plt.savefig(output_path, format="pdf", bbox_inches="tight")
            plt.close(fig)

        print(f"Saved plots for Glacier {glacier_name} ({feature_id}).")

    except Exception as e:
        print(f"Error processing Glacier {glacier_name} ({feature_id}): {e}")
# Out:
# Saved plots for Glacier Diebitsch (173).
# Saved plots for Glacier Morris Jesup (171).
# Saved plots for Glacier Verhoeff (166).
# Saved plots for Glacier Bowdoin (163).
# Saved plots for Glacier Hart (159).
# Saved plots for Glacier Sharp (104).
# Saved plots for Glacier Melville (103).
# Saved plots for Glacier Farquhar (102).
# Saved plots for Glacier Tracy (47).
# Saved plots for Glacier Heilprin (46).
# Saved plots for Glacier Leidy (45).
# Saved plots for Glacier Harald Moltke (48).
# Saved plots for Glacier Savissuaq WWWW (182).
# Saved plots for Glacier Savissuaq WWW (241).
# Saved plots for Glacier Savissuaq WW (239).
# Saved plots for Glacier Savissuaq W (238).
# Saved plots for Glacier Savissuaq (184).
# Saved plots for Glacier Helland (195).
# Saved plots for Glacier Yngvar Nielsen W (194).
# Saved plots for Glacier Yngvar Nielsen (196).
# Saved plots for Glacier Carlos (44).
# Saved plots for Glacier Gade—Morell (146).
# Saved plots for Glacier Döcker Smith W (147).
# Saved plots for Glacier Döcker Smith (77).
# Saved plots for Glacier Rink (43).
# Saved plots for Glacier Issuuarsuit (42).
# Saved plots for Glacier Kong Oscar N (41).
# Saved plots for Glacier Kong Oscar (126).
# Saved plots for Glacier Nordenskiöld (40).
# Saved plots for Glacier Nansen (36).
# Saved plots for Glacier Sverdrup (35).
# Saved plots for Glacier Steenstrup—Dietrichson (37).
# Saved plots for Glacier Kjer (34).
# Saved plots for Glacier Hayes N (213).
# Saved plots for Glacier Hayes S (33).
# Saved plots for Glacier Alison (32).
# Saved plots for Glacier Illullip (31).
# Saved plots for Glacier Cornell (30).
# Saved plots for Glacier Ussing N (29).
# Saved plots for Glacier Ussing (28).
# Saved plots for Glacier Qeqertarsuup (27).
# Saved plots for Glacier Kakiffaat (26).
# Saved plots for Glacier Nunatakassaap (25).
# Saved plots for Glacier Upernavik N (85).
# Saved plots for Glacier Upernavik C (206).
# Saved plots for Glacier Upernavik S (207).
# Saved plots for Glacier Upernavik SS (24).
# Saved plots for Glacier Inngia (22).
# Saved plots for Glacier Umiammakku (0).
# Saved plots for Glacier Rink Isbræ (2).
# Saved plots for Glacier Kangerlussuup (3).
# Saved plots for Glacier Kangerluarsuup (84).
# Saved plots for Glacier Sermeq Silarleq (5).
# Saved plots for Glacier Kangilleq—Sisoortartukassak (6).
# Saved plots for Glacier Lille (7).
# Saved plots for Glacier Store (8).
# Saved plots for Glacier Sermeq Avannarleq II (9).
# Saved plots for Glacier Sermeq Kujalleq (80).
# Saved plots for Glacier Kangilernata (81).
# Saved plots for Glacier Eqip (71).
# Saved plots for Glacier Sermeq Avannarleq I (221).
# Saved plots for Glacier Jakobshavn (217).
# Saved plots for Glacier Saqqarliup—Alanngorliup (218).

# %% [markdown]
# Flowline Graphs with Picked Flowlines and Elevation Buffers

# %%
import os
import geopandas as gp
import pandas as pd
import matplotlib.pyplot as plt
import xarray as xr
import rasterio

# === Paths ===
all_fl_path = '/Users/jagon/Documents/Projects/Collabs/Jessica Badgeley/New Points v3/Output/Flowlines/as Lines'
picked_fl_path = '/Users/jagon/Documents/Projects/Collabs/Jessica Badgeley/New Points v3/Flowlines of Interest/Picks'
int_path = '/Users/jagon/Documents/Projects/Collabs/Jessica Badgeley/New Points v3/Points/Intersections Cleaned'
buff_path = '/Users/jagon/Documents/Projects/Collabs/Jessica Badgeley/New Points v3/Points/Buffers'
out_path = '/Users/jagon/Documents/Projects/Collabs/Jessica Badgeley/New Points v3/Flowlines of Interest/Graphs with Picks and Buffers/with Lines'
out_chad_path = '/Users/jagon/Documents/Projects/Collabs/Jessica Badgeley/New Points v3/Flowlines of Interest/Graphs with Picks and Buffers/with Lines Chad'
titles_csv = '/Users/jagon/Documents/Projects/Collabs/Jessica Badgeley/New Points v3/Flowlines of Interest/fl_picks_3.1.csv'

os.makedirs(out_path, exist_ok=True)
os.makedirs(out_chad_path, exist_ok=True)

# === Static overlays ===
NWCW = gp.read_file('data/kuba-flowlines/NW-CW_Basins.shp')
contour100m = gp.read_file('data/kuba-flowlines/contour_100masl_arcticdem_10m_v4.1_nwcw.shp')
contour1500m = gp.read_file('data/kuba-flowlines/contour_1500masl_arcticdem_10m_v4.1_nwcw.shp')
contour = gp.read_file('data/kuba-flowlines/contour_every100_arcticdem_10m_v4.1_nwcw.shp')

# === Raster ===
with rasterio.open("data/kuba-flowlines/GL_vel_mosaic_Annual_01Dec15_30Nov21_vv_v05.0_nwcw_average.tif") as src_vv:
    Vv = src_vv.read(1)
    transform = src_vv.transform
    x = (np.arange(src_vv.width) * transform.a) + transform.c
    y = (np.arange(src_vv.height) * transform.e) + transform.f

if y[0] > y[-1]:
    y = y[::-1]
    Vv = Vv[::-1, :]

Vv = xr.DataArray(Vv, coords=[("y", y), ("x", x)])

# === Metadata ===
titles_df = pd.read_csv(titles_csv)

# === Loop ===
for _, row in titles_df.iterrows():
    feature_id = int(row["feature_ID"])
    glacier_name = row["glacier_name"]

    try:
        picks = []
        intersections = []
        buffers = []

        for fname in os.listdir(picked_fl_path):
            if fname.startswith(f"gl_{feature_id}_") and fname.endswith(".geojson"):
                fl_id = fname.split("_")[-1].split(".")[0]  # Extract flowline ID
                picks.append(gp.read_file(os.path.join(picked_fl_path, fname)))

                int_path_file = f"intsect_clean_gl_{feature_id}_{fl_id}.geojson"
                buff_path_file = f"buff_intsect_clean_gl_{feature_id}_{fl_id}.geojson"

                if os.path.exists(os.path.join(int_path, int_path_file)):
                    intersections.append(gp.read_file(os.path.join(int_path, int_path_file)))
                if os.path.exists(os.path.join(buff_path, buff_path_file)):
                    buffers.append(gp.read_file(os.path.join(buff_path, buff_path_file)))

        if not picks:
            print(f"No picks found for glacier {feature_id}. Skipping plot.")
            continue

        picks_gdf = pd.concat(picks).reset_index(drop=True)
        intersections_gdf = pd.concat(intersections).reset_index(drop=True) if intersections else None
        buffers_gdf = pd.concat(buffers).reset_index(drop=True) if buffers else None

        minx, miny, maxx, maxy = picks_gdf.total_bounds
        center_x = (minx + maxx) / 2
        center_y = (miny + maxy) / 2
        width = maxx - minx
        height = maxy - miny
        max_extent = max(width, height) / 2 + 5000
        minx = center_x - max_extent
        maxx = center_x + max_extent
        miny = center_y - max_extent
        maxy = center_y + max_extent

        Vv_crop = Vv.sel(x=slice(minx, maxx), y=slice(miny, maxy))

        for suffix, title_id, out_dir in [("", feature_id, out_path), ("_chad", feature_id + 1, out_chad_path)]:
            fig, ax = plt.subplots(1, figsize=(12, 12))
            ax.set_aspect('equal', adjustable='box')

            Vv_crop.plot(
                ax=ax,
                cmap="speed_colorblind",
                vmin=10,
                vmax=1500,
                zorder=1,
                cbar_kwargs={"shrink": 0.6, "label": r"velocity [m a$^{-1}$]", "pad": 0.02}
            )

            contour.plot(ax=ax, color="b", edgecolor="k", linewidth=0.25, zorder=3)
            contour100m.plot(ax=ax, color="b", edgecolor="k", linewidth=1, zorder=3)
            contour1500m.plot(ax=ax, color="b", edgecolor="k", linewidth=1, zorder=3)
            NWCW.plot(ax=ax, facecolor="none", edgecolor="g", linewidth=1, zorder=4)
            picks_gdf.plot(ax=ax, color="black", edgecolor="k", linewidth=2.5, zorder=5)

            if buffers_gdf is not None:
                buffers_gdf.plot(ax=ax, color="green", edgecolor="k", linewidth=0.5, alpha=0.5, zorder=2)

            if intersections_gdf is not None:
                intersections_gdf.plot(ax=ax, color="white", edgecolor="k", linewidth=0.01, markersize=5, zorder=6)

            ax.set_xlabel("x coordinate of projection [m]", fontsize=12)
            ax.set_ylabel("y coordinate of projection [m]", fontsize=12)
            ax.set_title(f"ID: {title_id}, {glacier_name}", fontsize=16)

            plt.tight_layout()
            filename = f"fl_{feature_id}_buffers{suffix}_v3.pdf"
            output_path = os.path.join(out_dir, filename)
            plt.savefig(output_path, format="pdf", bbox_inches="tight")
            plt.close(fig)

        print(f"Saved plots for Glacier {glacier_name} ({feature_id}).")

    except Exception as e:
        print(f"Error processing Glacier {glacier_name} ({feature_id}): {e}")
# Out:
# Saved plots for Glacier Diebitsch (173).
# Saved plots for Glacier Morris Jesup (171).
# Saved plots for Glacier Verhoeff (166).
# Saved plots for Glacier Bowdoin (163).
# Saved plots for Glacier Hart (159).
# Saved plots for Glacier Sharp (104).
# Saved plots for Glacier Melville (103).
# Saved plots for Glacier Farquhar (102).
# Saved plots for Glacier Tracy (47).
# Saved plots for Glacier Heilprin (46).
# Saved plots for Glacier Leidy (45).
# Saved plots for Glacier Harald Moltke (48).
# Saved plots for Glacier Savissuaq WWWW (182).
# Saved plots for Glacier Savissuaq WWW (241).
# Saved plots for Glacier Savissuaq WW (239).
# Saved plots for Glacier Savissuaq W (238).
# Saved plots for Glacier Savissuaq (184).
# Saved plots for Glacier Helland (195).
# Saved plots for Glacier Yngvar Nielsen W (194).
# Saved plots for Glacier Yngvar Nielsen (196).
# Saved plots for Glacier Carlos (44).
# Saved plots for Glacier Gade—Morell (146).
# Saved plots for Glacier Döcker Smith W (147).
# Saved plots for Glacier Döcker Smith (77).
# Saved plots for Glacier Rink (43).
# Saved plots for Glacier Issuuarsuit (42).
# Saved plots for Glacier Kong Oscar N (41).
# Saved plots for Glacier Kong Oscar (126).
# Saved plots for Glacier Nordenskiöld (40).
# Saved plots for Glacier Nansen (36).
# Saved plots for Glacier Sverdrup (35).
# Saved plots for Glacier Steenstrup—Dietrichson (37).
# Saved plots for Glacier Kjer (34).
# Saved plots for Glacier Hayes N (213).
# Saved plots for Glacier Hayes S (33).
# Saved plots for Glacier Alison (32).
# Saved plots for Glacier Illullip (31).
# Saved plots for Glacier Cornell (30).
# Saved plots for Glacier Ussing N (29).
# Saved plots for Glacier Ussing (28).
# Saved plots for Glacier Qeqertarsuup (27).
# Saved plots for Glacier Kakiffaat (26).
# Saved plots for Glacier Nunatakassaap (25).
# Saved plots for Glacier Upernavik N (85).
# Saved plots for Glacier Upernavik C (206).
# Saved plots for Glacier Upernavik S (207).
# Saved plots for Glacier Upernavik SS (24).
# Saved plots for Glacier Inngia (22).
# Saved plots for Glacier Umiammakku (0).
# Saved plots for Glacier Rink Isbræ (2).
# Saved plots for Glacier Kangerlussuup (3).
# Saved plots for Glacier Kangerluarsuup (84).
# Saved plots for Glacier Sermeq Silarleq (5).
# Saved plots for Glacier Kangilleq—Sisoortartukassak (6).
# Saved plots for Glacier Lille (7).
# Saved plots for Glacier Store (8).
# Saved plots for Glacier Sermeq Avannarleq II (9).
# Saved plots for Glacier Sermeq Kujalleq (80).
# Saved plots for Glacier Kangilernata (81).
# Saved plots for Glacier Eqip (71).
# Saved plots for Glacier Sermeq Avannarleq I (221).
# Saved plots for Glacier Jakobshavn (217).
# Saved plots for Glacier Saqqarliup—Alanngorliup (218).
